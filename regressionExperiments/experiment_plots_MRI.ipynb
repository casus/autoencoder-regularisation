# %%
import torch

# %%
# direct reconstruction experiments
deg_Quads = [40, 50, 60, 65, 70, 80]

# %%
LSTQS_direct = []

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.pyplot import figure

# %%
Analytical_direct = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/Analytic_MRI_direct_recon_psnr.pt')
RK_direct = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/RK_MRI_direct_recon_psnr.pt')
LSTQS_direct = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/LSTQS_MRI_direct_recon_psnr.pt')
Sobolev_direct = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/sobolev_MRI_direct_recon_psnr.pt')

figure(figsize=(8, 6), dpi=80)
plt.plot(deg_Quads, Analytical_direct, label = 'Unperturbed Polynomial Evaluation Analytical')
plt.plot(deg_Quads, RK_direct, label = 'Unperturbed Polynomial Evaluation Runge Kutta')
plt.plot(deg_Quads, LSTQS_direct, label = 'Unperturbed Polynomial Evaluation LSTQS')
plt.plot(deg_Quads, Sobolev_direct, label = 'Unperturbed Polynomial Evaluation Sobolev')

plt.legend()

plt.xticks(deg_Quads, fontsize=12 ) 
plt.yticks(fontsize= 12) 
plt.xlabel('Chebyshev Polynomial degree',fontsize=15)
plt.ylabel('PSNR',fontsize=15)
# Out:
# Text(0, 0.5, 'PSNR')

# %%
# adding 1 percent Gaussian Noise to coefficients

# %%
Analytical_noise1 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/Analytic_MRI_all_noise1_recons_psnr.pt')
RK_noise1 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/RK_MRI_all_noise1_recons_psnr.pt')
LSTQS_noise1 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/LSTQS_MRI_all_noise1_recons_psnr.pt')
Sobolev_noise1 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/sobolev_MRI_all_noise1_recons_psnr.pt')

figure(figsize=(8, 6), dpi=80)
plt.plot(deg_Quads, Analytical_noise1, label = '1 % Gaussian Noise on Coefficients : Analytical')
plt.plot(deg_Quads, RK_noise1, label = '1 % Gaussian Noise on Coefficients : Runge Kutta')
plt.plot(deg_Quads, LSTQS_noise1, label = '1 % Gaussian Noise on Coefficients : LSTQS')
plt.plot(deg_Quads, Sobolev_noise1, label = '1 % Gaussian Noise on Coefficients : Sobolev')

plt.legend()

plt.xticks(deg_Quads, fontsize=12 ) 
plt.yticks(fontsize= 12) 
plt.xlabel('Chebyshev Polynomial degree',fontsize=15)
plt.ylabel('PSNR',fontsize=15)
# Out:
# Text(0, 0.5, 'PSNR')

# %%
# adding 2 percent Gaussian Noise to coefficients

# %%
Analytical_noise2 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/Analytic_MRI_all_noise2_recons_psnr.pt')
RK_noise2 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/RK_MRI_all_noise2_recons_psnr.pt')
LSTQS_noise2 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/LSTQS_MRI_all_noise2_recons_psnr.pt')
Sobolev_noise2 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/sobolev_MRI_all_noise2_recons_psnr.pt')

figure(figsize=(8, 6), dpi=80)
plt.plot(deg_Quads, Analytical_noise2, label = '2 % Gaussian Noise on Coefficients : Analytical')
plt.plot(deg_Quads, RK_noise2, label = '2 % Gaussian Noise on Coefficients : Runge Kutta')
plt.plot(deg_Quads, LSTQS_noise2, label = '2 % Gaussian Noise on Coefficients : LSTQS')
plt.plot(deg_Quads, Sobolev_noise2, label = '2 % Gaussian Noise on Coefficients : Sobolev')

plt.legend()

plt.xticks(deg_Quads, fontsize=12 ) 
plt.yticks(fontsize= 12) 
plt.xlabel('Chebyshev Polynomial degree',fontsize=15)
plt.ylabel('PSNR',fontsize=15)
# Out:
# Text(0, 0.5, 'PSNR')

# %%
Analytical_noise4p3 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/Analytic_MRI_all_noise4p3_recons_psnr.pt')
RK_noise4p3 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/RK_MRI_all_noise4p3_recons_psnr.pt')
LSTQS_noise4p3 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/LSTQS_MRI_all_noise4p3_recons_psnr.pt')
Sobolev_noise4p3 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/sobolev_MRI_all_noise4p3_recons_psnr.pt')

figure(figsize=(8, 6), dpi=80)
plt.plot(deg_Quads, Analytical_noise4p3, label = '2 % Gaussian Noise on Coefficients : Analytical')
plt.plot(deg_Quads, RK_noise4p3, label = '2 % Gaussian Noise on Coefficients : Runge Kutta')
plt.plot(deg_Quads, LSTQS_noise4p3, label = '2 % Gaussian Noise on Coefficients : LSTQS')
plt.plot(deg_Quads, Sobolev_noise4p3, label = '2 % Gaussian Noise on Coefficients : Sobolev')

plt.legend()

plt.xticks(deg_Quads, fontsize=12 ) 
plt.yticks(fontsize= 12) 
plt.xlabel('Chebyshev Polynomial degree',fontsize=15)
plt.ylabel('PSNR',fontsize=15)
# Out:
# Text(0, 0.5, 'PSNR')

# %%
Sobolev_noise4p3
# Out:
# [12.629645665665086,
#  12.171879442471784,
#  13.02496752678545,
#  11.863842423425876,
#  12.737362467569579,
#  14.112424901981163,
#  15.472300943509946,
#  14.533757504527047,
#  14.491068915927672,
#  14.765883602594457,
#  13.933461547977357,
#  15.193903901607559,
#  15.940658505874142,
#  15.776454152405577,
#  16.237259708048178,
#  17.079512683204776]

# %%
Sobolev_noise1
# Out:
# [12.635197507902857,
#  12.132308302254089,
#  12.898074717435431,
#  11.997678465371282,
#  12.684554760863435,
#  14.113656310097728,
#  15.427330352613103,
#  14.460855115378298,
#  14.39557672755835,
#  14.57553700308803,
#  13.88685145838675,
#  15.129941103800725,
#  15.950059923527819,
#  15.880307201273371,
#  16.352939045974676,
#  17.06910658442602]

# %%
Sobolev_direct
# Out:
# [12.644062397282818,
#  12.082815865899875,
#  12.880550310614945,
#  11.988318944540035,
#  12.661095283433488,
#  14.097114095406745,
#  15.39888883103952,
#  14.436706554443594,
#  14.342850171880336,
#  14.566283823255823,
#  13.847059887361741,
#  15.10203415085386,
#  15.937678661904705,
#  15.876372978339464,
#  16.29145103687781,
#  17.03237245392166]
