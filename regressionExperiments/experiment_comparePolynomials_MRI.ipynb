# %%
import torch

# %%
# direct reconstruction experiments
deg_Quads = [40, 50, 60, 65, 70, 80]

psnr_list = [15, 16.5, 18.0, 19.5, 21.0, 22.5, 24.0]

# %%
psnr_list = [float(i) for i in psnr_list]

# %%
LSTQS_direct = []

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.pyplot import figure

# %%
import matplotlib
matplotlib.rcdefaults()

# %%
# direct reconstructions all 

Cheb1_LSTSQ_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/LSTQS_MRI_direct_recon_psnr.pt')
Cheb1_RK_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/RK_MRI_direct_recon_psnr.pt')
Cheb1_Analytic_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/Analytic_MRI_direct_recon_psnr.pt')
Cheb1_Sobolev_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/sobolev_MRI_direct_recon_psnr.pt')

Cheb2_LSTSQ_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_LSTQS_MRI_direct_recon_psnr.pt')
Cheb2_RK_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_RK_MRI_direct_recon_psnr.pt')
Cheb2_Analytic_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_Analytic_MRI_direct_recon_psnr.pt')
Cheb2_Sobolev_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_sobolev_MRI_direct_recon_psnr.pt')

legendre_LSTSQ_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_LSTQS_MRI_direct_recon_psnr.pt')
legendre_RK_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_RK_MRI_direct_recon_psnr.pt')
legendre_Analytic_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_Analytic_MRI_direct_recon_psnr.pt')
legendre_Sobolev_direct_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_sobolev_MRI_direct_recon_psnr.pt')

# %%
Cheb1_LSTSQ_direct_MRI[0]
# Out:
# 21.689461972994057

# %%
figure(figsize=(15, 10), dpi=100)
plt.plot(deg_Quads, Cheb1_LSTSQ_direct_MRI, label = 'Chebyshev 1 : LSTSQ ')
plt.plot(deg_Quads, Cheb1_RK_direct_MRI, label = 'Chebyshev 1 : RK ')
plt.plot(deg_Quads, Cheb1_Analytic_direct_MRI, label = 'Chebyshev 1 : Analytical ')
#plt.plot(deg_Quads, Cheb1_Sobolev_direct_MRI, label = 'Chebyshev 1 : Sobolev ')
plt.plot(deg_Quads, Cheb2_LSTSQ_direct_MRI, label = 'Chebyshev 2 : LSTSQ ')
plt.plot(deg_Quads, Cheb2_RK_direct_MRI, label = 'Chebyshev 2 : RK ')
plt.plot(deg_Quads, Cheb2_Analytic_direct_MRI, label = 'Chebyshev 2 : Analytical ')
#plt.plot(deg_Quads, Cheb2_Sobolev_direct_MRI, label = 'Chebyshev 2 : Sobolev ')
plt.plot(deg_Quads, legendre_LSTSQ_direct_MRI, label = 'Legendre : LSTSQ ')
plt.plot(deg_Quads, legendre_RK_direct_MRI, label = 'Legendre : RK ')
plt.plot(deg_Quads, legendre_Analytic_direct_MRI, label = 'Legendre : Analytical ')
#plt.plot(deg_Quads, legendre_Sobolev_direct_MRI, label = 'legendre : Sobolev ')


plt.legend(fontsize=13)

plt.title('Direct Evaluation of Polynomials', fontsize=20)

plt.xticks(deg_Quads, fontsize=20 ) 
plt.yticks(fontsize= 20) 
plt.xlabel('Polynomial degree',fontsize=20)
plt.ylabel('PSNR',fontsize=20)
# Out:
# Text(0, 0.5, 'PSNR')

# %%
# direct reconstructions all noise 1 percent
#/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders
Cheb1_LSTSQ_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/LSTQS_MRI_all_noise1_recons_psnr.pt')
Cheb1_RK_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/RK_MRI_all_noise1_recons_psnr.pt')
Cheb1_Analytic_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/Analytic_MRI_all_noise1_recons_psnr.pt')
Cheb1_Sobolev_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/sobolev_MRI_all_noise1_recons_psnr.pt')

Cheb2_LSTSQ_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_LSTQS_MRI_all_noise1_recons_psnr.pt')
Cheb2_RK_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_RK_MRI_all_noise1_recons_psnr.pt')
Cheb2_Analytic_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_Analytic_MRI_all_noise1_recons_psnr.pt')
Cheb2_Sobolev_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_sobolev_MRI_all_noise1_recons_psnr.pt')

legendre_LSTSQ_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_LSTQS_MRI_all_noise1_recons_psnr.pt')
legendre_RK_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_RK_MRI_all_noise1_recons_psnr.pt')
legendre_Analytic_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_Analytic_MRI_all_noise1_recons_psnr.pt')
legendre_Sobolev_noise1_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_sobolev_MRI_all_noise1_recons_psnr.pt')

# %%
figure(figsize=(15, 10), dpi=100)

plt.plot(deg_Quads, Cheb1_LSTSQ_noise1_MRI, label = 'Chebyshev 1, LSTSQ ')
plt.plot(deg_Quads, Cheb1_RK_noise1_MRI, label = 'Chebyshev 1, RK45 ')
plt.plot(deg_Quads, Cheb1_Analytic_noise1_MRI, label = 'Chebyshev 1, Pseudo-inverse')
#plt.plot(deg_Quads, Cheb1_Sobolev_noise1_MRI, label = 'Chebyshev 1 : Sobolev ')
plt.plot(deg_Quads, Cheb2_LSTSQ_noise1_MRI, label = 'Chebyshev 2, LSTSQ ')
plt.plot(deg_Quads, Cheb2_RK_noise1_MRI, label = 'Chebyshev 2, RK45 ')
plt.plot(deg_Quads, Cheb2_Analytic_noise1_MRI, label = 'Chebyshev 2, Pseudo-inverse ')
#plt.plot(deg_Quads, Cheb2_Sobolev_noise1_MRI, label = 'Chebyshev 2 : Sobolev ')
plt.plot(deg_Quads, legendre_LSTSQ_noise1_MRI, label = 'Legendre, LSTSQ ')
plt.plot(deg_Quads, legendre_RK_noise1_MRI, label = 'Legendre, RK45 ')
plt.plot(deg_Quads, legendre_Analytic_noise1_MRI, label = 'Legendre, Pseudo-inverse ')
#plt.plot(deg_Quads, legendre_Sobolev_noise1_MRI, label = 'legendre : Sobolev ')


plt.legend(fontsize=13)

#plt.title('Evaluation of Polynomials, Coefficients perturbed with 1% Gaussian Noise', fontsize=20)

plt.xticks(deg_Quads, fontsize=20 ) 
plt.yticks(psnr_list, fontsize= 20) 

plt.xlabel('Polynomial degree',fontsize=20)
plt.ylabel('PSNR',fontsize=20)
#plt.savefig('/media/chethan/New Volume/Thesis/Pictures_for_report/determine_architecture/MRI/noise_1.png')
# Out:
# Text(0, 0.5, 'PSNR')

# %%
# direct reconstructions all noise 2 percent

Cheb1_LSTSQ_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/LSTQS_MRI_all_noise2_recons_psnr.pt')
Cheb1_RK_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/RK_MRI_all_noise2_recons_psnr.pt')
Cheb1_Analytic_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/Analytic_MRI_all_noise2_recons_psnr.pt')
Cheb1_Sobolev_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/sobolev_MRI_all_noise2_recons_psnr.pt')

Cheb2_LSTSQ_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_LSTQS_MRI_all_noise2_recons_psnr.pt')
Cheb2_RK_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_RK_MRI_all_noise2_recons_psnr.pt')
Cheb2_Analytic_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_Analytic_MRI_all_noise2_recons_psnr.pt')
Cheb2_Sobolev_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/cheb2_sobolev_MRI_all_noise2_recons_psnr.pt')

legendre_LSTSQ_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_LSTQS_MRI_all_noise2_recons_psnr.pt')
legendre_RK_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_RK_MRI_all_noise2_recons_psnr.pt')
legendre_Analytic_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_Analytic_MRI_all_noise2_recons_psnr.pt')
legendre_Sobolev_noise2_MRI = torch.load('/home/ramana44/topological-analysis-of-curved-spaces-and-hybridization-of-autoencoders/regressionExperiments/legendre_sobolev_MRI_all_noise2_recons_psnr.pt')

# %%
figure(figsize=(15, 10), dpi=100)
plt.plot(deg_Quads, Cheb1_LSTSQ_noise2_MRI, label = 'Chebyshev 1, LSTSQ ')
plt.plot(deg_Quads, Cheb1_RK_noise2_MRI, label = 'Chebyshev 1, RK45 ')
plt.plot(deg_Quads, Cheb1_Analytic_noise2_MRI, label = 'Chebyshev 1, Pseudo-inverse ')
#plt.plot(deg_Quads, Cheb1_Sobolev_noise2_MRI, label = 'Chebyshev 1 : Sobolev ')
plt.plot(deg_Quads, Cheb2_LSTSQ_noise2_MRI, label = 'Chebyshev 2, LSTSQ ')
plt.plot(deg_Quads, Cheb2_RK_noise2_MRI, label = 'Chebyshev 2, RK45 ')
plt.plot(deg_Quads, Cheb2_Analytic_noise2_MRI, label = 'Chebyshev 2, Pseudo-inverse ')
#plt.plot(deg_Quads, Cheb2_Sobolev_noise2_MRI, label = 'Chebyshev 2 : Sobolev ')
plt.plot(deg_Quads, legendre_LSTSQ_noise2_MRI, label = 'Legendre, LSTSQ ')
plt.plot(deg_Quads, legendre_RK_noise2_MRI, label = 'Legendre, RK45 ')
plt.plot(deg_Quads, legendre_Analytic_noise2_MRI, label = 'Legendre, Pseudo-inverse ')
#plt.plot(deg_Quads, legendre_Sobolev_noise2_MRI, label = 'legendre : Sobolev ')


plt.legend(fontsize=13)

#plt.title('Evaluation of Polynomials, Coefficients perturbed with 2% Gaussian Noise', fontsize=20)

plt.xticks(deg_Quads, fontsize=20 ) 
plt.yticks(psnr_list, fontsize= 20) 
plt.xlabel('Polynomial degree',fontsize=20)
plt.ylabel('PSNR',fontsize=20)
#plt.savefig('/media/chethan/New Volume/Thesis/Pictures_for_report/determine_architecture/MRI/noise_2.png')
# Out:
# Text(0, 0.5, 'PSNR')
