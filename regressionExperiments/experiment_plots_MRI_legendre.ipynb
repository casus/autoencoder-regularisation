# %%
import torch

# %%
# direct reconstruction experiments
deg_Quads = [40, 50, 60, 65, 70, 80]

# %%
LSTQS_direct = []

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.pyplot import figure

# %%
Analytical_direct = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_Analytic_MRI_direct_recon_psnr.pt')
RK_direct = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_RK_MRI_direct_recon_psnr.pt')
LSTQS_direct = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_LSTQS_MRI_direct_recon_psnr.pt')
Sobolev_direct = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_sobolev_MRI_direct_recon_psnr.pt')

figure(figsize=(8, 6), dpi=80)
plt.plot(deg_Quads, Analytical_direct, label = 'Unperturbed Polynomial Evaluation Analytical')
plt.plot(deg_Quads, RK_direct, label = 'Unperturbed Polynomial Evaluation Runge Kutta')
plt.plot(deg_Quads, LSTQS_direct, label = 'Unperturbed Polynomial Evaluation LSTQS')
plt.plot(deg_Quads, Sobolev_direct, label = 'Unperturbed Polynomial Evaluation Sobolev')

plt.legend()

plt.xticks(deg_Quads, fontsize=12 ) 
plt.yticks(fontsize= 12) 
plt.xlabel('Legendre Polynomial degree',fontsize=15)
plt.ylabel('PSNR',fontsize=15)
# Out:
# Text(0, 0.5, 'PSNR')

# %%
# adding 1 percent Gaussian Noise to coefficients

# %%
Analytical_noise1 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_Analytic_MRI_all_noise1_recons_psnr.pt')
RK_noise1 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_RK_MRI_all_noise1_recons_psnr.pt')
LSTQS_noise1 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_LSTQS_MRI_all_noise1_recons_psnr.pt')
Sobolev_noise1 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_sobolev_MRI_all_noise1_recons_psnr.pt')

figure(figsize=(8, 6), dpi=80)
plt.plot(deg_Quads, Analytical_noise1, label = '1 % Gaussian Noise on Coefficients : Analytical')
plt.plot(deg_Quads, RK_noise1, label = '1 % Gaussian Noise on Coefficients : Runge Kutta')
plt.plot(deg_Quads, LSTQS_noise1, label = '1 % Gaussian Noise on Coefficients : LSTQS')
plt.plot(deg_Quads, Sobolev_noise1, label = '1 % Gaussian Noise on Coefficients : Sobolev')

plt.legend()

plt.xticks(deg_Quads, fontsize=12 ) 
plt.yticks(fontsize= 12) 
plt.xlabel('Legendre Polynomial degree',fontsize=15)
plt.ylabel('PSNR',fontsize=15)
# Out:
# Text(0, 0.5, 'PSNR')

# %%
# adding 2 percent Gaussian Noise to coefficients

# %%
Analytical_noise2 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_Analytic_MRI_all_noise2_recons_psnr.pt')
RK_noise2 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_RK_MRI_all_noise2_recons_psnr.pt')
LSTQS_noise2 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_LSTQS_MRI_all_noise2_recons_psnr.pt')
Sobolev_noise2 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_sobolev_MRI_all_noise2_recons_psnr.pt')

figure(figsize=(8, 6), dpi=80)
plt.plot(deg_Quads, Analytical_noise2, label = '2 % Gaussian Noise on Coefficients : Analytical')
plt.plot(deg_Quads, RK_noise2, label = '2 % Gaussian Noise on Coefficients : Runge Kutta')
plt.plot(deg_Quads, LSTQS_noise2, label = '2 % Gaussian Noise on Coefficients : LSTQS')
plt.plot(deg_Quads, Sobolev_noise2, label = '2 % Gaussian Noise on Coefficients : Sobolev')

plt.legend()

plt.xticks(deg_Quads, fontsize=12 ) 
plt.yticks(fontsize= 12) 
plt.xlabel('Legendre Polynomial degree',fontsize=15)
plt.ylabel('PSNR',fontsize=15)
# Out:
# Text(0, 0.5, 'PSNR')

# %%
Analytical_noise4p3 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_Analytic_MRI_all_noise4p3_recons_psnr.pt')
RK_noise4p3 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_RK_MRI_all_noise4p3_recons_psnr.pt')
LSTQS_noise4p3 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_LSTQS_MRI_all_noise4p3_recons_psnr.pt')
Sobolev_noise4p3 = torch.load('/media/chethan/New Volume/Thesis/regressionExperiments/legendre_sobolev_MRI_all_noise4p3_recons_psnr.pt')

figure(figsize=(8, 6), dpi=80)
plt.plot(deg_Quads, Analytical_noise4p3, label = '2 % Gaussian Noise on Coefficients : Analytical')
plt.plot(deg_Quads, RK_noise4p3, label = '2 % Gaussian Noise on Coefficients : Runge Kutta')
plt.plot(deg_Quads, LSTQS_noise4p3, label = '2 % Gaussian Noise on Coefficients : LSTQS')
plt.plot(deg_Quads, Sobolev_noise4p3, label = '2 % Gaussian Noise on Coefficients : Sobolev')

plt.legend()

plt.xticks(deg_Quads, fontsize=12 ) 
plt.yticks(fontsize= 12) 
plt.xlabel('Legendre Polynomial degree',fontsize=15)
plt.ylabel('PSNR',fontsize=15)
# Out:
# Text(0, 0.5, 'PSNR')

# %%
Sobolev_noise4p3
# Out:
# [18.779699436820312,
#  20.385758053670564,
#  21.66917046633929,
#  21.913307338693016,
#  21.643462813045296,
#  22.5878069726258]

# %%
Sobolev_noise1
# Out:
# [19.29975460416747,
#  20.7968657513377,
#  21.99040746200572,
#  22.29419131883653,
#  22.11492101533173,
#  23.178407860366402]

# %%
Sobolev_direct
# Out:
# [19.346862548633055,
#  20.875955749895777,
#  22.10972492154509,
#  22.378746573531387,
#  22.2353256396283,
#  23.247823919212614]
