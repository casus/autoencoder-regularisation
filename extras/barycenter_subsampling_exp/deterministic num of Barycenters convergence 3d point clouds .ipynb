# %%
import sympy as sp
import minterpy as mp
import numpy as np
from minterpy.pointcloud_utils import *

from mpl_toolkits import mplot3d
# %matplotlib inline

from mpl_toolkits.mplot3d import axes3d

import torch
import torchvision
from torchvision import transforms, datasets

import random
import numpy as np
import matplotlib.pyplot as plt

import os
from operator import itemgetter

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

import ot

from sklearn.neighbors import NearestNeighbors

import ripser
import persim
from persim import plot_diagrams

from operator import itemgetter


#do pip installs as follows to use vedo for plotting point clouds
#pip install vedo
#pip install ipyvtklink

import numpy as np
from vedo import *

import matplotlib.pyplot
from mpl_toolkits.mplot3d import Axes3D

# %%
def give_centeroid(arr):
    length = arr.shape[0]
    sum_x = np.sum(arr[:, 0])
    sum_y = np.sum(arr[:, 1])
    sum_z = np.sum(arr[:, 2])
    return np.array([[sum_x/length, sum_y/length, sum_z/length]])

# %%
def give_next_neighbours_barycenter_indices(batch_x, input_barycenter, remaining_indices, no_of_barycenetrs_required):
    

  num_neighbours = int(batch_x.shape[0] / no_of_barycenetrs_required)
    
  wasserDistance = []
  distance_cum_index = np.array([])

  for j in remaining_indices:
    
    wassDistance = dist = np.linalg.norm(batch_x[j]-input_barycenter)

    
    distance_cum_index = np.concatenate((distance_cum_index, np.array([wassDistance, j])), axis = 0)
   
  distance_cum_index = distance_cum_index.reshape(int(distance_cum_index.shape[0]/2), 2)
  distance_cum_index = sorted(distance_cum_index, key=itemgetter(0))
  
  distance_cum_index = np.array(distance_cum_index)
  
  remaining_indices = distance_cum_index[:,1]

  remaining_indices = remaining_indices.astype(int)
  
    
  A = np.array([])
  for i in range(num_neighbours):
    if(i >= distance_cum_index[:,1].shape[0]):
        break
    A = np.concatenate((A, batch_x[int(distance_cum_index[:,1][i])]), axis = 0 )
  
  A = A.reshape(int(A.shape[0]/3) , 3)
  
  #print("The shape of A is ")
  #print(A.shape)
  next_barycenter = give_centeroid(A) 
  
  next_barycenter = np.array(next_barycenter)
  #print(next_barycenter.shape)
  next_barycenter = next_barycenter.reshape(next_barycenter.shape[0]* next_barycenter.shape[1])
  #print(next_barycenter.shape)  
  return A, next_barycenter, remaining_indices

# %%
def get_convergent_barycenters(point_cloud, no_of_barycenetrs_required, initial_pt):   
    
    no_neighbours = int(point_cloud.shape[0] / no_of_barycenetrs_required)
    
    #num_neighbours = int(batch_x.shape[0] / no_of_barycenetrs_required)

    
    bary = initial_pt
    rem_indices = np.array(range(0,point_cloud.shape[0]))
    #print("Size of batch : ", point_cloud.shape[0])
    sampled_barycenters = np.array([])
    sampled_barycenters = torch.tensor(sampled_barycenters)
    covered_indices = np.array([])

    for i in range(int(point_cloud.shape[0])):

        if(len(rem_indices) < 2):
            #print("END")
            break

        #print("Iteration number : ", i+1)
        #print("Input barycenter : ")


        old_bary = bary



        neighbours, bary, rem_indices = give_next_neighbours_barycenter_indices(point_cloud, bary, rem_indices, no_neighbours)


        wassDistance = np.linalg.norm(old_bary - bary)  

        covered_indices = np.concatenate((covered_indices, rem_indices[:4] ) ,axis = 0)


        #print("Tracking distance between new barycenter and previous barycenter : ",wassDistance )
        if(wassDistance == 0.0):

            unique_covered_indices = np.unique(covered_indices, axis=0)
            sampled_barycenters = torch.cat((sampled_barycenters, torch.tensor(bary)), 0)

            s1 = set(rem_indices)
            s2 = set(unique_covered_indices)
            rem_set = s1 - s2
            rem_inds = list(rem_set)
            #rem_indices = rem_set
            rem_indices = rem_indices[no_neighbours:]

            #print("Sampled barycenters are")
            #print(sampled_barycenters)
    sampled_barycenters = sampled_barycenters.reshape(int((sampled_barycenters.shape[0]/3)),3)
    
    return sampled_barycenters

# %%
def _compute_distance_matrix(x, p=2):
    x_flat = x.view(x.size(0), -1)

    distances = torch.norm(x_flat[:, None] - x_flat, dim=2, p=p)

    return distances

# %%
def get_persistence_diagram(point_cloud, maximum_dim):

    point_cloud = torch.tensor(point_cloud)

    dist_matrix = _compute_distance_matrix(point_cloud, p=2)
    diagrams = ripser.ripser(dist_matrix.cpu().detach().numpy(), distance_matrix=True, maxdim=maximum_dim)['dgms']
    return diagrams, plot_diagrams(diagrams, show=True)

# %% [markdown]
# # Torus in 3D

# %%
x, y, z = sp.symbols('x y z')

# %%
## Torus
R = 1.5
r = 0.7
expr_torus = (x**2 + y**2 + z**2 + R**2 - r**2)**2 - 4*R**2*(x**2 + y**2)

# %%
expr_torus
# Out:
# -9.0*x**2 - 9.0*y**2 + 3.0976*(0.568181818181818*x**2 + 0.568181818181818*y**2 + 0.568181818181818*z**2 + 1)**2

# %%
poly_torus = sp.Poly(expr_torus, x, y, z)

# %%
sp.expand(expr_torus)
# Out:
# 1.0*x**4 + 2.0*x**2*y**2 + 2.0*x**2*z**2 - 5.48*x**2 + 1.0*y**4 + 2.0*y**2*z**2 - 5.48*y**2 + 1.0*z**4 + 3.52*z**2 + 3.0976

# %%
#Convert sympy polynomial to minterpy polynomial

newt_poly_torus = sympy_to_mp(poly_torus, mp.NewtonPolynomial)

# %% [markdown]
# # Trials on Torus :

# %%
#Sample points on the zero isocontour
def points_on_torus(num_points):
    
    point_data_torus = sample_points_on_poly(num_points,        # Number of points to be sampled
                                       newt_poly_torus,  # Polynomial in Newton basis
                                       bounds=3.0, # Boundary of the Cubic domain to be sampled
                                       tol=1e-15)  # Tolerance in solution
    
    return point_data_torus

# %% [markdown]
# # 1. 1000 barycenters from 10000 points

# %%
#Sample points on the zero isocontour

point_data_torus = sample_points_on_poly(10000,        # Number of points to be sampled
                                   newt_poly_torus,  # Polynomial in Newton basis
                                   bounds=3.0, # Boundary of the Cubic domain to be sampled
                                   tol=1e-15)  # Tolerance in solution

# %%
point_data_torus.shape
# Out:
# (10000, 3)

# %%
x_t = point_data_torus[:,0]
y_t = point_data_torus[:,1]
z_t = point_data_torus[:,2]


plot_points = [x_t,y_t,z_t]
Points(plot_points).show(axes=1)
# Out:
# ViewInteractiveWidget(height=960, layout=Layout(height='auto', width='100%'), width=960)

# %% [markdown]
# # demo of barycenter convergence on a torus

# %%
no_of_barycenetrs_required = 50

nachbarn = int(point_data_torus.shape[0] / no_of_barycenetrs_required)

int(nachbarn)
# Out:
# 200

# %%
#demo of barycenter convergence on a torus

bary = point_data_torus[0]
rem_indices = np.array(range(0,point_data_torus.shape[0]))
print("Size of batch : ", point_data_torus.shape[0])
sampled_barycenters = np.array([])
sampled_barycenters = torch.tensor(sampled_barycenters)
covered_indices = np.array([])

for i in range(int(point_data_torus.shape[0])):
        
    if(len(rem_indices) < 2):
        print("END")
        break
    
    print("Iteration number : ", i+1)
    print("Input barycenter : ")
    print(bary)

    old_bary = bary
    
    
    
    neighbours, bary, rem_indices = give_next_neighbours_barycenter_indices(point_data_torus, bary, rem_indices, nachbarn)
    
    print("remaining indices")
    print(rem_indices)
    print("neighbours found : ")
    print(neighbours)

    
    wassDistance = np.linalg.norm(old_bary - bary)  
    
    covered_indices = np.concatenate((covered_indices, rem_indices[:nachbarn] ) ,axis = 0)
    #print("covered indices")
    #print(covered_indices)

    print("Tracking distance between new barycenter and previous barycenter : ",wassDistance )
    if(wassDistance == 0.0):

        unique_covered_indices = np.unique(covered_indices, axis=0)
        sampled_barycenters = torch.cat((sampled_barycenters, torch.tensor(bary)), 0)

        s1 = set(rem_indices)
        s2 = set(unique_covered_indices)
        rem_set = s1 - s2
        rem_inds = list(rem_set)
        rem_indices = rem_indices[nachbarn:]
        print("Sampled barycenters are")
        print(sampled_barycenters.reshape(int((sampled_barycenters.shape[0]/3)),3))
sampled_barycenters = sampled_barycenters.reshape(int((sampled_barycenters.shape[0]/3)),3)
# Out:
# Size of batch :  10000
# Iteration number :  1
# Input barycenter :
# [ 1.71638583 -1.26730025 -0.29768437]
# remaining indices
# [   0 8406 1003 ... 1282 3762 2707]
# neighbours found :
# [[ 1.71638583 -1.26730025 -0.29768437]
#  [ 1.74321812 -1.27270713 -0.23777984]
#  [ 1.76569701 -1.220685   -0.26823262]
#  [ 1.71582199 -1.31151312 -0.2342107 ]
#  [ 1.68741049 -1.24057798 -0.36976165]
#  [ 1.75575295 -1.26533657 -0.22100553]
#  [ 1.72818792 -1.19976385 -0.35411729]
#  [ 1.73615915 -1.18078754 -0.36114575]
#  [ 1.75802416 -1.17403645 -0.3361544 ]
#  [ 1.67045342 -1.23645701 -0.39445436]
#  [ 1.79392425 -1.19795834 -0.24116867]
#  [ 1.78179709 -1.24296147 -0.19427923]
#  [ 1.67055204 -1.36737907 -0.23657267]
#  [ 1.770439   -1.26591355 -0.17999376]
#  [ 1.79581627 -1.21403936 -0.21023797]
#  [ 1.63418859 -1.27749431 -0.40027843]
#  [ 1.69229401 -1.36707177 -0.18362228]
#  [ 1.67064308 -1.19680332 -0.42647082]
#  [ 1.81229888 -1.20369138 -0.18315161]
#  [ 1.70400136 -1.36027386 -0.16465586]
#  [ 1.82417055 -1.18361081 -0.18714745]
#  [ 1.76596635 -1.11243019 -0.38114423]
#  [ 1.64979673 -1.40934102 -0.20336131]
#  [ 1.58017176 -1.36017011 -0.38449523]
#  [ 1.57853394 -1.3583     -0.38821381]
#  [ 1.81769072 -1.21137601 -0.14714114]
#  [ 1.60060588 -1.41805773 -0.28709553]
#  [ 1.6230452  -1.21938582 -0.4571953 ]
#  [ 1.74056132 -1.32896342 -0.11843486]
#  [ 1.59388847 -1.27259762 -0.4459006 ]
#  [ 1.84095694 -1.14188671 -0.21445607]
#  [ 1.68664561 -1.14270856 -0.44868468]
#  [ 1.83250565 -1.10402187 -0.28494713]
#  [ 1.61421394 -1.43538653 -0.23296205]
#  [ 1.82377551 -1.21064282 -0.12349091]
#  [ 1.66548458 -1.14594401 -0.4667892 ]
#  [ 1.77592111 -1.28871544 -0.08962525]
#  [ 1.55048053 -1.36886743 -0.40872517]
#  [ 1.75572288 -1.31766974 -0.08200244]
#  [ 1.85130678 -1.15726943 -0.15218554]
#  [ 1.82465711 -1.06734679 -0.33633052]
#  [ 1.65408159 -1.42948317 -0.13838044]
#  [ 1.81087722 -1.24099981 -0.0809521 ]
#  [ 1.86498216 -1.09004167 -0.23274668]
#  [ 1.6405036  -1.44144706 -0.14968392]
#  [ 1.76073141 -1.31460477 -0.06081616]
#  [ 1.53589652 -1.41049039 -0.38396363]
#  [ 1.71073131 -1.07920593 -0.46560929]
#  [ 1.82151054 -1.22746245 -0.0700202 ]
#  [ 1.83056859 -1.04347842 -0.34848478]]
# Tracking distance between new barycenter and previous barycenter :  0.0367700951862875
# Iteration number :  2
# Input barycenter :
# [ 1.724581   -1.25189314 -0.26531927]
# remaining indices
# [   0 8406 1003 ... 1282 3762 2707]
# neighbours found :
# [[ 1.71638583 -1.26730025 -0.29768437]
#  [ 1.74321812 -1.27270713 -0.23777984]
#  [ 1.76569701 -1.220685   -0.26823262]
#  [ 1.75575295 -1.26533657 -0.22100553]
#  [ 1.71582199 -1.31151312 -0.2342107 ]
#  [ 1.79392425 -1.19795834 -0.24116867]
#  [ 1.78179709 -1.24296147 -0.19427923]
#  [ 1.79581627 -1.21403936 -0.21023797]
#  [ 1.770439   -1.26591355 -0.17999376]
#  [ 1.72818792 -1.19976385 -0.35411729]
#  [ 1.75802416 -1.17403645 -0.3361544 ]
#  [ 1.68741049 -1.24057798 -0.36976165]
#  [ 1.73615915 -1.18078754 -0.36114575]
#  [ 1.81229888 -1.20369138 -0.18315161]
#  [ 1.67055204 -1.36737907 -0.23657267]
#  [ 1.67045342 -1.23645701 -0.39445436]
#  [ 1.82417055 -1.18361081 -0.18714745]
#  [ 1.69229401 -1.36707177 -0.18362228]
#  [ 1.70400136 -1.36027386 -0.16465586]
#  [ 1.81769072 -1.21137601 -0.14714114]
#  [ 1.63418859 -1.27749431 -0.40027843]
#  [ 1.74056132 -1.32896342 -0.11843486]
#  [ 1.84095694 -1.14188671 -0.21445607]
#  [ 1.82377551 -1.21064282 -0.12349091]
#  [ 1.67064308 -1.19680332 -0.42647082]
#  [ 1.83250565 -1.10402187 -0.28494713]
#  [ 1.64979673 -1.40934102 -0.20336131]
#  [ 1.76596635 -1.11243019 -0.38114423]
#  [ 1.77592111 -1.28871544 -0.08962525]
#  [ 1.85130678 -1.15726943 -0.15218554]
#  [ 1.75572288 -1.31766974 -0.08200244]
#  [ 1.81087722 -1.24099981 -0.0809521 ]
#  [ 1.60060588 -1.41805773 -0.28709553]
#  [ 1.58017176 -1.36017011 -0.38449523]
#  [ 1.61421394 -1.43538653 -0.23296205]
#  [ 1.86498216 -1.09004167 -0.23274668]
#  [ 1.68664561 -1.14270856 -0.44868468]
#  [ 1.76073141 -1.31460477 -0.06081616]
#  [ 1.57853394 -1.3583     -0.38821381]
#  [ 1.82151054 -1.22746245 -0.0700202 ]
#  [ 1.6230452  -1.21938582 -0.4571953 ]
#  [ 1.82465711 -1.06734679 -0.33633052]
#  [ 1.59388847 -1.27259762 -0.4459006 ]
#  [ 1.65408159 -1.42948317 -0.13838044]
#  [ 1.74810694 -1.33273959 -0.05020077]
#  [ 1.66548458 -1.14594401 -0.4667892 ]
#  [ 1.6405036  -1.44144706 -0.14968392]
#  [ 1.85143025 -1.18097356 -0.0745637 ]
#  [ 1.83056859 -1.04347842 -0.34848478]
#  [ 1.83255324 -1.03944295 -0.34895382]]
# Tracking distance between new barycenter and previous barycenter :  0.02109067588327836
# Iteration number :  3
# Input barycenter :
# [ 1.73728064 -1.24578499 -0.24962767]
# remaining indices
# [8406 2690 1003 ... 1282 3762 2707]
# neighbours found :
# [[ 1.74321812 -1.27270713 -0.23777984]
#  [ 1.75575295 -1.26533657 -0.22100553]
#  [ 1.76569701 -1.220685   -0.26823262]
#  [ 1.71638583 -1.26730025 -0.29768437]
#  [ 1.71582199 -1.31151312 -0.2342107 ]
#  [ 1.78179709 -1.24296147 -0.19427923]
#  [ 1.79392425 -1.19795834 -0.24116867]
#  [ 1.79581627 -1.21403936 -0.21023797]
#  [ 1.770439   -1.26591355 -0.17999376]
#  [ 1.81229888 -1.20369138 -0.18315161]
#  [ 1.75802416 -1.17403645 -0.3361544 ]
#  [ 1.72818792 -1.19976385 -0.35411729]
#  [ 1.82417055 -1.18361081 -0.18714745]
#  [ 1.73615915 -1.18078754 -0.36114575]
#  [ 1.68741049 -1.24057798 -0.36976165]
#  [ 1.81769072 -1.21137601 -0.14714114]
#  [ 1.67055204 -1.36737907 -0.23657267]
#  [ 1.69229401 -1.36707177 -0.18362228]
#  [ 1.70400136 -1.36027386 -0.16465586]
#  [ 1.84095694 -1.14188671 -0.21445607]
#  [ 1.74056132 -1.32896342 -0.11843486]
#  [ 1.82377551 -1.21064282 -0.12349091]
#  [ 1.67045342 -1.23645701 -0.39445436]
#  [ 1.77592111 -1.28871544 -0.08962525]
#  [ 1.85130678 -1.15726943 -0.15218554]
#  [ 1.83250565 -1.10402187 -0.28494713]
#  [ 1.75572288 -1.31766974 -0.08200244]
#  [ 1.81087722 -1.24099981 -0.0809521 ]
#  [ 1.63418859 -1.27749431 -0.40027843]
#  [ 1.76596635 -1.11243019 -0.38114423]
#  [ 1.64979673 -1.40934102 -0.20336131]
#  [ 1.67064308 -1.19680332 -0.42647082]
#  [ 1.82151054 -1.22746245 -0.0700202 ]
#  [ 1.86498216 -1.09004167 -0.23274668]
#  [ 1.76073141 -1.31460477 -0.06081616]
#  [ 1.82465711 -1.06734679 -0.33633052]
#  [ 1.74810694 -1.33273959 -0.05020077]
#  [ 1.85143025 -1.18097356 -0.0745637 ]
#  [ 1.60060588 -1.41805773 -0.28709553]
#  [ 1.61421394 -1.43538653 -0.23296205]
#  [ 1.68664561 -1.14270856 -0.44868468]
#  [ 1.65408159 -1.42948317 -0.13838044]
#  [ 1.58017176 -1.36017011 -0.38449523]
#  [ 1.6230452  -1.21938582 -0.4571953 ]
#  [ 1.57853394 -1.3583     -0.38821381]
#  [ 1.6405036  -1.44144706 -0.14968392]
#  [ 1.83056859 -1.04347842 -0.34848478]
#  [ 1.59388847 -1.27259762 -0.4459006 ]
#  [ 1.83255324 -1.03944295 -0.34895382]
#  [ 1.66548458 -1.14594401 -0.4667892 ]]
# Tracking distance between new barycenter and previous barycenter :  5.551115123125783e-17
# Iteration number :  4
# Input barycenter :
# [ 1.73728064 -1.24578499 -0.24962767]
# remaining indices
# [8406 2690 1003 ... 1282 3762 2707]
# neighbours found :
# [[ 1.74321812 -1.27270713 -0.23777984]
#  [ 1.75575295 -1.26533657 -0.22100553]
#  [ 1.76569701 -1.220685   -0.26823262]
#  [ 1.71638583 -1.26730025 -0.29768437]
#  [ 1.71582199 -1.31151312 -0.2342107 ]
#  [ 1.78179709 -1.24296147 -0.19427923]
#  [ 1.79392425 -1.19795834 -0.24116867]
#  [ 1.79581627 -1.21403936 -0.21023797]
#  [ 1.770439   -1.26591355 -0.17999376]
#  [ 1.81229888 -1.20369138 -0.18315161]
#  [ 1.75802416 -1.17403645 -0.3361544 ]
#  [ 1.72818792 -1.19976385 -0.35411729]
#  [ 1.82417055 -1.18361081 -0.18714745]
#  [ 1.73615915 -1.18078754 -0.36114575]
#  [ 1.68741049 -1.24057798 -0.36976165]
#  [ 1.81769072 -1.21137601 -0.14714114]
#  [ 1.67055204 -1.36737907 -0.23657267]
#  [ 1.69229401 -1.36707177 -0.18362228]
#  [ 1.70400136 -1.36027386 -0.16465586]
#  [ 1.84095694 -1.14188671 -0.21445607]
#  [ 1.74056132 -1.32896342 -0.11843486]
#  [ 1.82377551 -1.21064282 -0.12349091]
#  [ 1.67045342 -1.23645701 -0.39445436]
#  [ 1.77592111 -1.28871544 -0.08962525]
#  [ 1.85130678 -1.15726943 -0.15218554]
#  [ 1.83250565 -1.10402187 -0.28494713]
#  [ 1.75572288 -1.31766974 -0.08200244]
#  [ 1.81087722 -1.24099981 -0.0809521 ]
#  [ 1.63418859 -1.27749431 -0.40027843]
#  [ 1.76596635 -1.11243019 -0.38114423]
#  [ 1.64979673 -1.40934102 -0.20336131]
#  [ 1.67064308 -1.19680332 -0.42647082]
#  [ 1.82151054 -1.22746245 -0.0700202 ]
#  [ 1.86498216 -1.09004167 -0.23274668]
#  [ 1.76073141 -1.31460477 -0.06081616]
#  [ 1.82465711 -1.06734679 -0.33633052]
#  [ 1.74810694 -1.33273959 -0.05020077]
#  [ 1.85143025 -1.18097356 -0.0745637 ]
#  [ 1.60060588 -1.41805773 -0.28709553]
#  [ 1.61421394 -1.43538653 -0.23296205]
#  [ 1.68664561 -1.14270856 -0.44868468]
#  [ 1.65408159 -1.42948317 -0.13838044]
#  [ 1.58017176 -1.36017011 -0.38449523]
#  [ 1.6230452  -1.21938582 -0.4571953 ]
#  [ 1.57853394 -1.3583     -0.38821381]
#  [ 1.6405036  -1.44144706 -0.14968392]
#  [ 1.83056859 -1.04347842 -0.34848478]
#  [ 1.59388847 -1.27259762 -0.4459006 ]
#  [ 1.83255324 -1.03944295 -0.34895382]
#  [ 1.66548458 -1.14594401 -0.4667892 ]]
# Tracking distance between new barycenter and previous barycenter :  0.0
# Sampled barycenters are
# tensor([[ 1.7373, -1.2458, -0.2496]], dtype=torch.float64)
# Iteration number :  5
# Input barycenter :
# [ 1.73728064 -1.24578499 -0.24962767]
# remaining indices
# [ 292 6104 1185 ... 1282 3762 2707]
# neighbours found :
# [[ 1.35069413 -1.41926624 -0.52828234]
#  [ 1.35594239 -1.50318694 -0.4636984 ]
#  [ 1.89985002 -1.05510745  0.19193183]
#  [ 1.55869452 -0.94732322 -0.62050676]
#  [ 1.56803656 -1.51986023  0.15000559]
#  [ 1.34793536 -1.35148246 -0.56824318]
#  [ 1.80850696 -0.8034671  -0.51049346]
#  [ 1.77693574 -1.20584482  0.26608685]
#  [ 1.50390826 -0.98285096 -0.63406175]
#  [ 1.79101508 -0.80221338 -0.52547426]
#  [ 1.80552643 -0.79757124 -0.51524301]
#  [ 1.46496065 -1.64049324 -0.02915487]
#  [ 1.66831191 -0.84904791 -0.59301188]
#  [ 1.97108477 -0.95198979  0.12394047]
#  [ 1.61895792 -0.87287186 -0.61228501]
#  [ 1.36106203 -1.19728578 -0.62625965]
#  [ 1.35809466 -1.6097927  -0.3501232 ]
#  [ 1.38180868 -1.13614112 -0.63759621]
#  [ 1.41464438 -1.07134887 -0.64391419]
#  [ 1.33110371 -1.53287892 -0.45708753]
#  [ 1.34951572 -1.21720864 -0.62392627]
#  [ 1.95087474 -0.7645327  -0.3682092 ]
#  [ 1.94173733 -0.761196   -0.38348739]
#  [ 1.32451672 -1.31977374 -0.59434746]
#  [ 1.84095537 -1.10606565  0.26555623]
#  [ 1.33583699 -1.57397211 -0.41403495]
#  [ 1.6127636  -1.42704299  0.25093693]
#  [ 1.95247684 -0.96774933  0.16956477]
#  [ 1.32460162 -1.28691669 -0.60804577]
#  [ 1.49238999 -1.61025073  0.0794145 ]
#  [ 1.98108785 -0.75646896 -0.32380968]
#  [ 1.35060214 -1.17354392 -0.63745434]
#  [ 1.34912113 -1.17232319 -0.63832137]
#  [ 1.30996296 -1.34883263 -0.58771374]
#  [ 2.04105508 -0.8007224  -0.10218544]
#  [ 2.04135175 -0.80290604 -0.09461775]
#  [ 1.30417029 -1.36141585 -0.58442507]
#  [ 1.44006485 -1.66267622 -0.02339864]
#  [ 1.30999044 -1.3015853  -0.60812679]
#  [ 1.55389985 -1.5099057   0.2134551 ]
#  [ 1.5576131  -0.87751423 -0.63810457]
#  [ 1.6451656  -0.82203065 -0.61237925]
#  [ 1.31170805 -1.26487059 -0.62143065]
#  [ 1.58479865 -1.456389    0.25382235]
#  [ 1.43893038 -0.98446046 -0.6562949 ]
#  [ 1.53479314 -1.53755657  0.19434606]
#  [ 1.81385724 -1.12104674  0.30026813]
#  [ 1.30533157 -1.27467118 -0.62025934]
#  [ 1.65688137 -1.33689677  0.30722342]
#  [ 1.96631191 -0.73088154 -0.36426718]]
# Tracking distance between new barycenter and previous barycenter :  0.18578937332096507
# Iteration number :  6
# Input barycenter :
# [ 1.57918881 -1.17162861 -0.31307446]
# remaining indices
# [5079 7397 8233 ... 3762 1282 2707]
# neighbours found :
# [[ 1.50390826 -0.98285096 -0.63406175]
#  [ 1.55869452 -0.94732322 -0.62050676]
#  [ 1.38180868 -1.13614112 -0.63759621]
#  [ 1.36106203 -1.19728578 -0.62625965]
#  [ 1.41464438 -1.07134887 -0.64391419]
#  [ 1.34793536 -1.35148246 -0.56824318]
#  [ 1.34951572 -1.21720864 -0.62392627]
#  [ 1.35060214 -1.17354392 -0.63745434]
#  [ 1.34912113 -1.17232319 -0.63832137]
#  [ 1.35069413 -1.41926624 -0.52828234]
#  [ 1.32460162 -1.28691669 -0.60804577]
#  [ 1.32451672 -1.31977374 -0.59434746]
#  [ 1.43893038 -0.98446046 -0.6562949 ]
#  [ 1.31170805 -1.26487059 -0.62143065]
#  [ 1.37116218 -1.0601955  -0.66000143]
#  [ 1.30999044 -1.3015853  -0.60812679]
#  [ 1.30996296 -1.34883263 -0.58771374]
#  [ 1.36334608 -1.06365876 -0.66141818]
#  [ 1.30533157 -1.27467118 -0.62025934]
#  [ 1.61895792 -0.87287186 -0.61228501]
#  [ 1.32971825 -1.12908795 -0.65594237]
#  [ 1.35594239 -1.50318694 -0.4636984 ]
#  [ 1.30417029 -1.36141585 -0.58442507]
#  [ 1.66831191 -0.84904791 -0.59301188]
#  [ 1.5576131  -0.87751423 -0.63810457]
#  [ 1.44328334 -0.93928685 -0.66386031]
#  [ 1.44274716 -0.93673394 -0.66447312]
#  [ 1.2819861  -1.22856506 -0.64345033]
#  [ 1.30557456 -1.09978656 -0.66867479]
#  [ 1.50945095 -0.87902677 -0.65506884]
#  [ 1.540008   -0.86171377 -0.64802202]
#  [ 1.27397918 -1.18867565 -0.65668878]
#  [ 1.33110371 -1.53287892 -0.45708753]
#  [ 1.26439233 -1.31176767 -0.62158043]
#  [ 1.6451656  -0.82203065 -0.61237925]
#  [ 1.36392304 -0.97509722 -0.67734816]
#  [ 1.25870322 -1.31039491 -0.62411101]
#  [ 1.79101508 -0.80221338 -0.52547426]
#  [ 1.80850696 -0.8034671  -0.51049346]
#  [ 1.49851239 -0.85502346 -0.66275725]
#  [ 1.33583699 -1.57397211 -0.41403495]
#  [ 1.80552643 -0.79757124 -0.51524301]
#  [ 1.23983577 -1.23434566 -0.65402017]
#  [ 1.23895473 -1.24390095 -0.65164739]
#  [ 1.35809466 -1.6097927  -0.3501232 ]
#  [ 1.60431087 -0.79712951 -0.63644902]
#  [ 1.23969256 -1.39844006 -0.59495794]
#  [ 1.2649785  -1.48742663 -0.5340057 ]
#  [ 1.2980958  -0.99918826 -0.68623864]
#  [ 1.26030857 -1.47964535 -0.54146603]]
# Tracking distance between new barycenter and previous barycenter :  0.33972083735520225
# Iteration number :  7
# Input barycenter :
# [ 1.40532473 -1.14669877 -0.60386654]
# remaining indices
# [8233 1538 1967 ... 4971 6356 9741]
# neighbours found :
# [[ 1.38180868 -1.13614112 -0.63759621]
#  [ 1.35060214 -1.17354392 -0.63745434]
#  [ 1.34912113 -1.17232319 -0.63832137]
#  [ 1.36106203 -1.19728578 -0.62625965]
#  [ 1.41464438 -1.07134887 -0.64391419]
#  [ 1.34951572 -1.21720864 -0.62392627]
#  [ 1.32971825 -1.12908795 -0.65594237]
#  [ 1.37116218 -1.0601955  -0.66000143]
#  [ 1.36334608 -1.06365876 -0.66141818]
#  [ 1.30557456 -1.09978656 -0.66867479]
#  [ 1.27397918 -1.18867565 -0.65668878]
#  [ 1.31170805 -1.26487059 -0.62143065]
#  [ 1.2819861  -1.22856506 -0.64345033]
#  [ 1.32460162 -1.28691669 -0.60804577]
#  [ 1.30533157 -1.27467118 -0.62025934]
#  [ 1.43893038 -0.98446046 -0.6562949 ]
#  [ 1.30999044 -1.3015853  -0.60812679]
#  [ 1.36392304 -0.97509722 -0.67734816]
#  [ 1.32451672 -1.31977374 -0.59434746]
#  [ 1.50390826 -0.98285096 -0.63406175]
#  [ 1.23983577 -1.23434566 -0.65402017]
#  [ 1.23895473 -1.24390095 -0.65164739]
#  [ 1.2980958  -0.99918826 -0.68623864]
#  [ 1.28583942 -1.00035041 -0.6879854 ]
#  [ 1.34793536 -1.35148246 -0.56824318]
#  [ 1.26439233 -1.31176767 -0.62158043]
#  [ 1.20074689 -1.1773902  -0.67601266]
#  [ 1.44328334 -0.93928685 -0.66386031]
#  [ 1.28499581 -0.98298477 -0.69000641]
#  [ 1.25870322 -1.31039491 -0.62411101]
#  [ 1.44274716 -0.93673394 -0.66447312]
#  [ 1.30996296 -1.34883263 -0.58771374]
#  [ 1.19030085 -1.19290944 -0.67506033]
#  [ 1.2601976  -0.98304765 -0.69306722]
#  [ 1.30417029 -1.36141585 -0.58442507]
#  [ 1.55869452 -0.94732322 -0.62050676]
#  [ 1.22080485 -1.31773542 -0.6341847 ]
#  [ 1.14931647 -1.25726872 -0.66979006]
#  [ 1.35069413 -1.41926624 -0.52828234]
#  [ 1.50945095 -0.87902677 -0.65506884]
#  [ 1.43484938 -0.86022821 -0.67829629]
#  [ 1.30786315 -0.87993686 -0.69582668]
#  [ 1.20176065 -0.94717558 -0.69935024]
#  [ 1.23969256 -1.39844006 -0.59495794]
#  [ 1.12026664 -1.1067544  -0.69599522]
#  [ 1.36480477 -0.8544992  -0.69126548]
#  [ 1.33337861 -0.85900815 -0.69468153]
#  [ 1.5576131  -0.87751423 -0.63810457]
#  [ 1.49851239 -0.85502346 -0.66275725]
#  [ 1.540008   -0.86171377 -0.64802202]]
# Tracking distance between new barycenter and previous barycenter :  0.08709317995138302
# Iteration number :  8
# Input barycenter :
# [ 1.33546604 -1.11645986 -0.64618195]
# remaining indices
# [1492 4903 8233 ... 9741 6356 4971]
# neighbours found :
# [[ 1.32971825 -1.12908795 -0.65594237]
#  [ 1.30557456 -1.09978656 -0.66867479]
#  [ 1.38180868 -1.13614112 -0.63759621]
#  [ 1.34912113 -1.17232319 -0.63832137]
#  [ 1.35060214 -1.17354392 -0.63745434]
#  [ 1.36334608 -1.06365876 -0.66141818]
#  [ 1.37116218 -1.0601955  -0.66000143]
#  [ 1.36106203 -1.19728578 -0.62625965]
#  [ 1.41464438 -1.07134887 -0.64391419]
#  [ 1.27397918 -1.18867565 -0.65668878]
#  [ 1.34951572 -1.21720864 -0.62392627]
#  [ 1.2819861  -1.22856506 -0.64345033]
#  [ 1.2980958  -0.99918826 -0.68623864]
#  [ 1.28583942 -1.00035041 -0.6879854 ]
#  [ 1.36392304 -0.97509722 -0.67734816]
#  [ 1.28499581 -0.98298477 -0.69000641]
#  [ 1.20074689 -1.1773902  -0.67601266]
#  [ 1.23983577 -1.23434566 -0.65402017]
#  [ 1.31170805 -1.26487059 -0.62143065]
#  [ 1.23895473 -1.24390095 -0.65164739]
#  [ 1.2601976  -0.98304765 -0.69306722]
#  [ 1.30533157 -1.27467118 -0.62025934]
#  [ 1.19030085 -1.19290944 -0.67506033]
#  [ 1.43893038 -0.98446046 -0.6562949 ]
#  [ 1.32460162 -1.28691669 -0.60804577]
#  [ 1.30999044 -1.3015853  -0.60812679]
#  [ 1.44328334 -0.93928685 -0.66386031]
#  [ 1.26439233 -1.31176767 -0.62158043]
#  [ 1.25870322 -1.31039491 -0.62411101]
#  [ 1.32451672 -1.31977374 -0.59434746]
#  [ 1.44274716 -0.93673394 -0.66447312]
#  [ 1.50390826 -0.98285096 -0.63406175]
#  [ 1.12026664 -1.1067544  -0.69599522]
#  [ 1.20176065 -0.94717558 -0.69935024]
#  [ 1.22080485 -1.31773542 -0.6341847 ]
#  [ 1.14931647 -1.25726872 -0.66979006]
#  [ 1.30996296 -1.34883263 -0.58771374]
#  [ 1.30786315 -0.87993686 -0.69582668]
#  [ 1.18399373 -0.9290231  -0.69998238]
#  [ 1.34793536 -1.35148246 -0.56824318]
#  [ 1.30417029 -1.36141585 -0.58442507]
#  [ 1.1532641  -0.94678591 -0.69995564]
#  [ 1.19944953 -0.90218872 -0.69999945]
#  [ 1.33337861 -0.85900815 -0.69468153]
#  [ 1.36480477 -0.8544992  -0.69126548]
#  [ 1.09136329 -1.00170907 -0.69975238]
#  [ 1.3318839  -0.84508506 -0.69571151]
#  [ 1.43484938 -0.86022821 -0.67829629]
#  [ 1.55869452 -0.94732322 -0.62050676]
#  [ 1.27398722 -0.84190489 -0.6994776 ]]
# Tracking distance between new barycenter and previous barycenter :  0.03484658054917375
# Iteration number :  9
# Input barycenter :
# [ 1.30622546 -1.09997411 -0.65553567]
# remaining indices
# [4903 1492 3820 ... 9895 6356 4971]
# neighbours found :
# [[ 1.30557456 -1.09978656 -0.66867479]
#  [ 1.32971825 -1.12908795 -0.65594237]
#  [ 1.36334608 -1.06365876 -0.66141818]
#  [ 1.37116218 -1.0601955  -0.66000143]
#  [ 1.38180868 -1.13614112 -0.63759621]
#  [ 1.34912113 -1.17232319 -0.63832137]
#  [ 1.35060214 -1.17354392 -0.63745434]
#  [ 1.27397918 -1.18867565 -0.65668878]
#  [ 1.2980958  -0.99918826 -0.68623864]
#  [ 1.28583942 -1.00035041 -0.6879854 ]
#  [ 1.41464438 -1.07134887 -0.64391419]
#  [ 1.36106203 -1.19728578 -0.62625965]
#  [ 1.28499581 -0.98298477 -0.69000641]
#  [ 1.34951572 -1.21720864 -0.62392627]
#  [ 1.2601976  -0.98304765 -0.69306722]
#  [ 1.2819861  -1.22856506 -0.64345033]
#  [ 1.20074689 -1.1773902  -0.67601266]
#  [ 1.36392304 -0.97509722 -0.67734816]
#  [ 1.19030085 -1.19290944 -0.67506033]
#  [ 1.23983577 -1.23434566 -0.65402017]
#  [ 1.23895473 -1.24390095 -0.65164739]
#  [ 1.31170805 -1.26487059 -0.62143065]
#  [ 1.43893038 -0.98446046 -0.6562949 ]
#  [ 1.30533157 -1.27467118 -0.62025934]
#  [ 1.20176065 -0.94717558 -0.69935024]
#  [ 1.12026664 -1.1067544  -0.69599522]
#  [ 1.32460162 -1.28691669 -0.60804577]
#  [ 1.30999044 -1.3015853  -0.60812679]
#  [ 1.44328334 -0.93928685 -0.66386031]
#  [ 1.44274716 -0.93673394 -0.66447312]
#  [ 1.18399373 -0.9290231  -0.69998238]
#  [ 1.25870322 -1.31039491 -0.62411101]
#  [ 1.26439233 -1.31176767 -0.62158043]
#  [ 1.1532641  -0.94678591 -0.69995564]
#  [ 1.14931647 -1.25726872 -0.66979006]
#  [ 1.30786315 -0.87993686 -0.69582668]
#  [ 1.32451672 -1.31977374 -0.59434746]
#  [ 1.19944953 -0.90218872 -0.69999945]
#  [ 1.50390826 -0.98285096 -0.63406175]
#  [ 1.22080485 -1.31773542 -0.6341847 ]
#  [ 1.09136329 -1.00170907 -0.69975238]
#  [ 1.33337861 -0.85900815 -0.69468153]
#  [ 1.36480477 -0.8544992  -0.69126548]
#  [ 1.30996296 -1.34883263 -0.58771374]
#  [ 1.05290504 -1.07557829 -0.69998105]
#  [ 1.3318839  -0.84508506 -0.69571151]
#  [ 1.27398722 -0.84190489 -0.6994776 ]
#  [ 1.34793536 -1.35148246 -0.56824318]
#  [ 1.30417029 -1.36141585 -0.58442507]
#  [ 1.43484938 -0.86022821 -0.67829629]]
# Tracking distance between new barycenter and previous barycenter :  0.010556297232773409
# Iteration number :  10
# Input barycenter :
# [ 1.29610967 -1.10253921 -0.65712516]
# remaining indices
# [4903 1492 3820 ... 9895 6356 4971]
# neighbours found :
# [[ 1.30557456 -1.09978656 -0.66867479]
#  [ 1.32971825 -1.12908795 -0.65594237]
#  [ 1.36334608 -1.06365876 -0.66141818]
#  [ 1.37116218 -1.0601955  -0.66000143]
#  [ 1.27397918 -1.18867565 -0.65668878]
#  [ 1.34912113 -1.17232319 -0.63832137]
#  [ 1.35060214 -1.17354392 -0.63745434]
#  [ 1.38180868 -1.13614112 -0.63759621]
#  [ 1.28583942 -1.00035041 -0.6879854 ]
#  [ 1.2980958  -0.99918826 -0.68623864]
#  [ 1.36106203 -1.19728578 -0.62625965]
#  [ 1.20074689 -1.1773902  -0.67601266]
#  [ 1.41464438 -1.07134887 -0.64391419]
#  [ 1.28499581 -0.98298477 -0.69000641]
#  [ 1.2819861  -1.22856506 -0.64345033]
#  [ 1.2601976  -0.98304765 -0.69306722]
#  [ 1.34951572 -1.21720864 -0.62392627]
#  [ 1.19030085 -1.19290944 -0.67506033]
#  [ 1.23983577 -1.23434566 -0.65402017]
#  [ 1.36392304 -0.97509722 -0.67734816]
#  [ 1.23895473 -1.24390095 -0.65164739]
#  [ 1.31170805 -1.26487059 -0.62143065]
#  [ 1.30533157 -1.27467118 -0.62025934]
#  [ 1.12026664 -1.1067544  -0.69599522]
#  [ 1.43893038 -0.98446046 -0.6562949 ]
#  [ 1.20176065 -0.94717558 -0.69935024]
#  [ 1.32460162 -1.28691669 -0.60804577]
#  [ 1.30999044 -1.3015853  -0.60812679]
#  [ 1.18399373 -0.9290231  -0.69998238]
#  [ 1.14931647 -1.25726872 -0.66979006]
#  [ 1.25870322 -1.31039491 -0.62411101]
#  [ 1.26439233 -1.31176767 -0.62158043]
#  [ 1.1532641  -0.94678591 -0.69995564]
#  [ 1.44328334 -0.93928685 -0.66386031]
#  [ 1.44274716 -0.93673394 -0.66447312]
#  [ 1.30786315 -0.87993686 -0.69582668]
#  [ 1.19944953 -0.90218872 -0.69999945]
#  [ 1.32451672 -1.31977374 -0.59434746]
#  [ 1.22080485 -1.31773542 -0.6341847 ]
#  [ 1.09136329 -1.00170907 -0.69975238]
#  [ 1.50390826 -0.98285096 -0.63406175]
#  [ 1.05290504 -1.07557829 -0.69998105]
#  [ 1.33337861 -0.85900815 -0.69468153]
#  [ 1.30996296 -1.34883263 -0.58771374]
#  [ 1.36480477 -0.8544992  -0.69126548]
#  [ 1.3318839  -0.84508506 -0.69571151]
#  [ 1.27398722 -0.84190489 -0.6994776 ]
#  [ 1.30417029 -1.36141585 -0.58442507]
#  [ 1.34793536 -1.35148246 -0.56824318]
#  [ 1.03174226 -1.14703789 -0.69869119]]
# Tracking distance between new barycenter and previous barycenter :  0.00990295097923192
# Iteration number :  11
# Input barycenter :
# [ 1.28804752 -1.1082754  -0.65753306]
# remaining indices
# [4903 1492 3440 ... 9895 6356 4971]
# neighbours found :
# [[ 1.30557456 -1.09978656 -0.66867479]
#  [ 1.32971825 -1.12908795 -0.65594237]
#  [ 1.27397918 -1.18867565 -0.65668878]
#  [ 1.36334608 -1.06365876 -0.66141818]
#  [ 1.34912113 -1.17232319 -0.63832137]
#  [ 1.35060214 -1.17354392 -0.63745434]
#  [ 1.37116218 -1.0601955  -0.66000143]
#  [ 1.38180868 -1.13614112 -0.63759621]
#  [ 1.28583942 -1.00035041 -0.6879854 ]
#  [ 1.20074689 -1.1773902  -0.67601266]
#  [ 1.2980958  -0.99918826 -0.68623864]
#  [ 1.36106203 -1.19728578 -0.62625965]
#  [ 1.2819861  -1.22856506 -0.64345033]
#  [ 1.28499581 -0.98298477 -0.69000641]
#  [ 1.34951572 -1.21720864 -0.62392627]
#  [ 1.19030085 -1.19290944 -0.67506033]
#  [ 1.41464438 -1.07134887 -0.64391419]
#  [ 1.2601976  -0.98304765 -0.69306722]
#  [ 1.23983577 -1.23434566 -0.65402017]
#  [ 1.23895473 -1.24390095 -0.65164739]
#  [ 1.36392304 -0.97509722 -0.67734816]
#  [ 1.31170805 -1.26487059 -0.62143065]
#  [ 1.30533157 -1.27467118 -0.62025934]
#  [ 1.12026664 -1.1067544  -0.69599522]
#  [ 1.20176065 -0.94717558 -0.69935024]
#  [ 1.32460162 -1.28691669 -0.60804577]
#  [ 1.43893038 -0.98446046 -0.6562949 ]
#  [ 1.30999044 -1.3015853  -0.60812679]
#  [ 1.14931647 -1.25726872 -0.66979006]
#  [ 1.25870322 -1.31039491 -0.62411101]
#  [ 1.26439233 -1.31176767 -0.62158043]
#  [ 1.18399373 -0.9290231  -0.69998238]
#  [ 1.1532641  -0.94678591 -0.69995564]
#  [ 1.22080485 -1.31773542 -0.6341847 ]
#  [ 1.32451672 -1.31977374 -0.59434746]
#  [ 1.09136329 -1.00170907 -0.69975238]
#  [ 1.19944953 -0.90218872 -0.69999945]
#  [ 1.44328334 -0.93928685 -0.66386031]
#  [ 1.44274716 -0.93673394 -0.66447312]
#  [ 1.30786315 -0.87993686 -0.69582668]
#  [ 1.05290504 -1.07557829 -0.69998105]
#  [ 1.50390826 -0.98285096 -0.63406175]
#  [ 1.30996296 -1.34883263 -0.58771374]
#  [ 1.33337861 -0.85900815 -0.69468153]
#  [ 1.03174226 -1.14703789 -0.69869119]
#  [ 1.30417029 -1.36141585 -0.58442507]
#  [ 1.34793536 -1.35148246 -0.56824318]
#  [ 1.36480477 -0.8544992  -0.69126548]
#  [ 1.3318839  -0.84508506 -0.69571151]
#  [ 1.27398722 -0.84190489 -0.6994776 ]]
# Tracking distance between new barycenter and previous barycenter :  2.220446049250313e-16
# Iteration number :  12
# Input barycenter :
# [ 1.28804752 -1.1082754  -0.65753306]
# remaining indices
# [4903 1492 3440 ... 9895 6356 4971]
# neighbours found :
# [[ 1.30557456 -1.09978656 -0.66867479]
#  [ 1.32971825 -1.12908795 -0.65594237]
#  [ 1.27397918 -1.18867565 -0.65668878]
#  [ 1.36334608 -1.06365876 -0.66141818]
#  [ 1.34912113 -1.17232319 -0.63832137]
#  [ 1.35060214 -1.17354392 -0.63745434]
#  [ 1.37116218 -1.0601955  -0.66000143]
#  [ 1.38180868 -1.13614112 -0.63759621]
#  [ 1.28583942 -1.00035041 -0.6879854 ]
#  [ 1.20074689 -1.1773902  -0.67601266]
#  [ 1.2980958  -0.99918826 -0.68623864]
#  [ 1.36106203 -1.19728578 -0.62625965]
#  [ 1.2819861  -1.22856506 -0.64345033]
#  [ 1.28499581 -0.98298477 -0.69000641]
#  [ 1.34951572 -1.21720864 -0.62392627]
#  [ 1.19030085 -1.19290944 -0.67506033]
#  [ 1.41464438 -1.07134887 -0.64391419]
#  [ 1.2601976  -0.98304765 -0.69306722]
#  [ 1.23983577 -1.23434566 -0.65402017]
#  [ 1.23895473 -1.24390095 -0.65164739]
#  [ 1.36392304 -0.97509722 -0.67734816]
#  [ 1.31170805 -1.26487059 -0.62143065]
#  [ 1.30533157 -1.27467118 -0.62025934]
#  [ 1.12026664 -1.1067544  -0.69599522]
#  [ 1.20176065 -0.94717558 -0.69935024]
#  [ 1.32460162 -1.28691669 -0.60804577]
#  [ 1.43893038 -0.98446046 -0.6562949 ]
#  [ 1.30999044 -1.3015853  -0.60812679]
#  [ 1.14931647 -1.25726872 -0.66979006]
#  [ 1.25870322 -1.31039491 -0.62411101]
#  [ 1.26439233 -1.31176767 -0.62158043]
#  [ 1.18399373 -0.9290231  -0.69998238]
#  [ 1.1532641  -0.94678591 -0.69995564]
#  [ 1.22080485 -1.31773542 -0.6341847 ]
#  [ 1.32451672 -1.31977374 -0.59434746]
#  [ 1.09136329 -1.00170907 -0.69975238]
#  [ 1.19944953 -0.90218872 -0.69999945]
#  [ 1.44328334 -0.93928685 -0.66386031]
#  [ 1.44274716 -0.93673394 -0.66447312]
#  [ 1.30786315 -0.87993686 -0.69582668]
#  [ 1.05290504 -1.07557829 -0.69998105]
#  [ 1.50390826 -0.98285096 -0.63406175]
#  [ 1.30996296 -1.34883263 -0.58771374]
#  [ 1.33337861 -0.85900815 -0.69468153]
#  [ 1.03174226 -1.14703789 -0.69869119]
#  [ 1.30417029 -1.36141585 -0.58442507]
#  [ 1.34793536 -1.35148246 -0.56824318]
#  [ 1.36480477 -0.8544992  -0.69126548]
#  [ 1.3318839  -0.84508506 -0.69571151]
#  [ 1.27398722 -0.84190489 -0.6994776 ]]
# Tracking distance between new barycenter and previous barycenter :  0.0
# Sampled barycenters are
# tensor([[ 1.7373, -1.2458, -0.2496],
#         [ 1.2880, -1.1083, -0.6575]], dtype=torch.float64)
# Iteration number :  13
# Input barycenter :
# [ 1.28804752 -1.1082754  -0.65753306]
# remaining indices
# [9842 5643 6749 ... 9895 6356 4971]
# neighbours found :
# [[ 0.71830155 -1.03454495 -0.65737408]
#  [ 1.0507374  -1.62138912 -0.55072925]
#  [ 0.71846808 -1.02092192 -0.65321702]
#  [ 1.65255606 -0.66213142 -0.6414429 ]
#  [ 0.76941654 -0.86154985 -0.60913722]
#  [ 1.68543962 -0.69203095 -0.62155326]
#  [ 1.18765827 -1.64261674 -0.46073077]
#  [ 1.22419364 -0.53231548 -0.68025613]
#  [ 0.84004684 -1.47708635 -0.67104248]
#  [ 0.72461029 -1.24539742 -0.6974972 ]
#  [ 0.80985749 -1.4424169  -0.68280081]
#  [ 0.73414548 -0.92162783 -0.62169342]
#  [ 0.96529775 -1.59462393 -0.59789528]
#  [ 0.73964112 -0.90017465 -0.61467108]
#  [ 0.77044384 -0.82853883 -0.59509008]
#  [ 1.35809466 -1.6097927  -0.3501232 ]
#  [ 0.70643452 -1.22396601 -0.69459792]
#  [ 0.71523716 -1.26155455 -0.6982264 ]
#  [ 1.08472577 -0.54965603 -0.63981744]
#  [ 1.5528356  -0.57599809 -0.68234493]
#  [ 0.73204983 -0.89881341 -0.61144142]
#  [ 1.33772786 -0.51481458 -0.69682168]
#  [ 0.95878929 -1.60389445 -0.59507698]
#  [ 0.76141213 -1.39724573 -0.69402831]
#  [ 1.4474071  -0.52912166 -0.69879299]
#  [ 0.83264421 -1.50269459 -0.66520172]
#  [ 0.73046756 -0.88389438 -0.60428298]
#  [ 1.79101508 -0.80221338 -0.52547426]
#  [ 1.64654808 -0.62222946 -0.64984462]
#  [ 0.92297337 -0.63186137 -0.58693033]
#  [ 0.72409026 -0.88506132 -0.60243067]
#  [ 0.67749343 -1.08426632 -0.66404038]
#  [ 1.44660742 -0.51936723 -0.69902066]
#  [ 1.72536034 -0.68110487 -0.6033435 ]
#  [ 0.76862455 -1.43664327 -0.68794829]
#  [ 0.71975403 -0.87507988 -0.59611274]
#  [ 0.93947141 -1.61459628 -0.59544569]
#  [ 1.50377216 -0.53042452 -0.69358121]
#  [ 0.78059062 -1.46178512 -0.68213246]
#  [ 1.80552643 -0.79757124 -0.51524301]
#  [ 1.80850696 -0.8034671  -0.51049346]
#  [ 1.73346512 -0.67858672 -0.59939895]
#  [ 1.14551577 -0.50298915 -0.65424727]
#  [ 0.77895528 -0.75847446 -0.56534549]
#  [ 0.72379713 -0.85020722 -0.58564794]
#  [ 1.58060912 -0.55639085 -0.67759673]
#  [ 1.58566753 -0.55383454 -0.67656626]
#  [ 0.86274203 -1.5764111  -0.63384551]
#  [ 0.84828806 -1.56553685 -0.64130308]
#  [ 1.27819146 -1.66831827 -0.35774439]]
# Tracking distance between new barycenter and previous barycenter :  0.22254556384596644
# Iteration number :  14
# Input barycenter :
# [ 1.09212411 -1.00970466 -0.61979248]
# remaining indices
# [9053 8634 6370 ... 1436 4971 6356]
# neighbours found :
# [[ 0.76941654 -0.86154985 -0.60913722]
#  [ 0.73414548 -0.92162783 -0.62169342]
#  [ 0.73964112 -0.90017465 -0.61467108]
#  [ 0.77044384 -0.82853883 -0.59509008]
#  [ 0.71846808 -1.02092192 -0.65321702]
#  [ 0.71830155 -1.03454495 -0.65737408]
#  [ 0.73204983 -0.89881341 -0.61144142]
#  [ 0.73046756 -0.88389438 -0.60428298]
#  [ 0.72409026 -0.88506132 -0.60243067]
#  [ 0.71975403 -0.87507988 -0.59611274]
#  [ 0.72379713 -0.85020722 -0.58564794]
#  [ 0.77895528 -0.75847446 -0.56534549]
#  [ 0.92297337 -0.63186137 -0.58693033]
#  [ 0.67749343 -1.08426632 -0.66404038]
#  [ 0.66320663 -0.93829256 -0.60564815]
#  [ 0.72461029 -1.24539742 -0.6974972 ]
#  [ 0.70643452 -1.22396601 -0.69459792]
#  [ 0.90005377 -0.60738999 -0.56432295]
#  [ 0.87748095 -0.61373847 -0.55299315]
#  [ 0.71523716 -1.26155455 -0.6982264 ]
#  [ 0.74394251 -0.72369839 -0.52577833]
#  [ 1.08472577 -0.54965603 -0.63981744]
#  [ 0.83802339 -0.63367678 -0.53672078]
#  [ 0.96913456 -0.55810628 -0.58680703]
#  [ 0.69300446 -0.77609627 -0.52804679]
#  [ 0.67496371 -0.79854525 -0.5324548 ]
#  [ 0.70381776 -0.7505473  -0.51776984]
#  [ 0.90333511 -0.57230618 -0.55186628]
#  [ 0.98052132 -0.54218189 -0.58816098]
#  [ 0.76171404 -0.67107699 -0.50490742]
#  [ 0.60416616 -1.02454038 -0.62732351]
#  [ 0.79272917 -0.6369473  -0.50658799]
#  [ 0.63519143 -1.18636837 -0.68278467]
#  [ 0.60603736 -1.11041351 -0.65938519]
#  [ 0.62920919 -1.18411202 -0.68168079]
#  [ 1.22419364 -0.53231548 -0.68025613]
#  [ 0.67185624 -1.272859   -0.69736254]
#  [ 0.66965428 -1.27729738 -0.69760916]
#  [ 0.80876688 -0.60737266 -0.50130478]
#  [ 0.65572611 -1.2550815  -0.69494814]
#  [ 0.65034268 -1.24747331 -0.69377014]
#  [ 0.6570293  -0.77134596 -0.50305861]
#  [ 1.14551577 -0.50298915 -0.65424727]
#  [ 0.58019228 -1.00910457 -0.61409243]
#  [ 0.97407893 -0.51284258 -0.57503665]
#  [ 0.76141213 -1.39724573 -0.69402831]
#  [ 0.58823845 -0.91671147 -0.56679258]
#  [ 0.62026295 -0.82587201 -0.52132151]
#  [ 0.60600331 -0.8561461  -0.5352792 ]
#  [ 1.02218111 -0.49620422 -0.59807086]]
# Tracking distance between new barycenter and previous barycenter :  0.35482570627362936
# Iteration number :  15
# Input barycenter :
# [ 0.76605982 -0.87048979 -0.60555942]
# remaining indices
# [9053 5776 6370 ... 1436 6174 3631]
# neighbours found :
# [[ 0.76941654 -0.86154985 -0.60913722]
#  [ 0.73046756 -0.88389438 -0.60428298]
#  [ 0.73964112 -0.90017465 -0.61467108]
#  [ 0.77044384 -0.82853883 -0.59509008]
#  [ 0.72409026 -0.88506132 -0.60243067]
#  [ 0.73204983 -0.89881341 -0.61144142]
#  [ 0.71975403 -0.87507988 -0.59611274]
#  [ 0.72379713 -0.85020722 -0.58564794]
#  [ 0.73414548 -0.92162783 -0.62169342]
#  [ 0.77895528 -0.75847446 -0.56534549]
#  [ 0.66320663 -0.93829256 -0.60564815]
#  [ 0.67496371 -0.79854525 -0.5324548 ]
#  [ 0.69300446 -0.77609627 -0.52804679]
#  [ 0.70381776 -0.7505473  -0.51776984]
#  [ 0.71846808 -1.02092192 -0.65321702]
#  [ 0.74394251 -0.72369839 -0.52577833]
#  [ 0.62026295 -0.82587201 -0.52132151]
#  [ 0.60600331 -0.8561461  -0.5352792 ]
#  [ 0.71830155 -1.03454495 -0.65737408]
#  [ 0.6570293  -0.77134596 -0.50305861]
#  [ 0.58823845 -0.91671147 -0.56679258]
#  [ 0.62389658 -0.79283621 -0.49879841]
#  [ 0.58005107 -0.88176433 -0.54071462]
#  [ 0.67526732 -0.72620226 -0.4812204 ]
#  [ 0.56624121 -0.88721458 -0.53828741]
#  [ 0.55611876 -0.88497608 -0.53212809]
#  [ 0.76171404 -0.67107699 -0.50490742]
#  [ 0.60416616 -1.02454038 -0.62732351]
#  [ 0.58019228 -1.00910457 -0.61409243]
#  [ 0.59833918 -0.77778925 -0.47006263]
#  [ 0.67749343 -1.08426632 -0.66404038]
#  [ 0.54343446 -0.9574546  -0.57510065]
#  [ 0.53305739 -0.93217321 -0.55531401]
#  [ 0.54138915 -0.84850225 -0.49645303]
#  [ 0.65103718 -0.71060223 -0.44992317]
#  [ 0.52541156 -0.9056643  -0.53368899]
#  [ 0.79272917 -0.6369473  -0.50658799]
#  [ 0.83802339 -0.63367678 -0.53672078]
#  [ 0.52758742 -0.86755859 -0.50512192]
#  [ 0.64652223 -0.70742871 -0.44342064]
#  [ 0.54824959 -0.79976906 -0.4568608 ]
#  [ 0.87748095 -0.61373847 -0.55299315]
#  [ 0.77157831 -0.61594107 -0.47656631]
#  [ 0.92297337 -0.63186137 -0.58693033]
#  [ 0.80876688 -0.60737266 -0.50130478]
#  [ 0.63980189 -0.69023374 -0.42153302]
#  [ 0.50327052 -0.85839062 -0.48478966]
#  [ 0.60603736 -1.11041351 -0.65938519]
#  [ 0.90005377 -0.60738999 -0.56432295]
#  [ 0.5220444  -0.79603321 -0.43547179]]
# Tracking distance between new barycenter and previous barycenter :  0.11679448017284985
# Iteration number :  16
# Input barycenter :
# [ 0.67465858 -0.82694133 -0.54733317]
# remaining indices
# [7132 8404 9375 ... 1795 2140 6174]
# neighbours found :
# [[ 0.67496371 -0.79854525 -0.5324548 ]
#  [ 0.69300446 -0.77609627 -0.52804679]
#  [ 0.62026295 -0.82587201 -0.52132151]
#  [ 0.72379713 -0.85020722 -0.58564794]
#  [ 0.6570293  -0.77134596 -0.50305861]
#  [ 0.60600331 -0.8561461  -0.5352792 ]
#  [ 0.62389658 -0.79283621 -0.49879841]
#  [ 0.71975403 -0.87507988 -0.59611274]
#  [ 0.70381776 -0.7505473  -0.51776984]
#  [ 0.72409026 -0.88506132 -0.60243067]
#  [ 0.73046756 -0.88389438 -0.60428298]
#  [ 0.77044384 -0.82853883 -0.59509008]
#  [ 0.58005107 -0.88176433 -0.54071462]
#  [ 0.73204983 -0.89881341 -0.61144142]
#  [ 0.76941654 -0.86154985 -0.60913722]
#  [ 0.73964112 -0.90017465 -0.61467108]
#  [ 0.59833918 -0.77778925 -0.47006263]
#  [ 0.67526732 -0.72620226 -0.4812204 ]
#  [ 0.56624121 -0.88721458 -0.53828741]
#  [ 0.77895528 -0.75847446 -0.56534549]
#  [ 0.58823845 -0.91671147 -0.56679258]
#  [ 0.74394251 -0.72369839 -0.52577833]
#  [ 0.66320663 -0.93829256 -0.60564815]
#  [ 0.55611876 -0.88497608 -0.53212809]
#  [ 0.73414548 -0.92162783 -0.62169342]
#  [ 0.54138915 -0.84850225 -0.49645303]
#  [ 0.65103718 -0.71060223 -0.44992317]
#  [ 0.54824959 -0.79976906 -0.4568608 ]
#  [ 0.52758742 -0.86755859 -0.50512192]
#  [ 0.64652223 -0.70742871 -0.44342064]
#  [ 0.52541156 -0.9056643  -0.53368899]
#  [ 0.53305739 -0.93217321 -0.55531401]
#  [ 0.76171404 -0.67107699 -0.50490742]
#  [ 0.50327052 -0.85839062 -0.48478966]
#  [ 0.54343446 -0.9574546  -0.57510065]
#  [ 0.63980189 -0.69023374 -0.42153302]
#  [ 0.5220444  -0.79603321 -0.43547179]
#  [ 0.58019228 -1.00910457 -0.61409243]
#  [ 0.66074143 -0.65548516 -0.40733338]
#  [ 0.46802005 -0.9054514  -0.50880866]
#  [ 0.60416616 -1.02454038 -0.62732351]
#  [ 0.71846808 -1.02092192 -0.65321702]
#  [ 0.79272917 -0.6369473  -0.50658799]
#  [ 0.45790878 -0.89284165 -0.49336174]
#  [ 0.71830155 -1.03454495 -0.65737408]
#  [ 0.77157831 -0.61594107 -0.47656631]
#  [ 0.54383924 -0.72094175 -0.36559969]
#  [ 0.83802339 -0.63367678 -0.53672078]
#  [ 0.49138428 -0.76847045 -0.38003218]
#  [ 0.64450182 -0.63979454 -0.37376817]]
# Tracking distance between new barycenter and previous barycenter :  0.03652542214303549
# Iteration number :  17
# Input barycenter :
# [ 0.64413037 -0.82550019 -0.52733171]
# remaining indices
# [9375 7132 4590 ... 8326 6174 2140]
# neighbours found :
# [[ 0.62026295 -0.82587201 -0.52132151]
#  [ 0.67496371 -0.79854525 -0.5324548 ]
#  [ 0.62389658 -0.79283621 -0.49879841]
#  [ 0.60600331 -0.8561461  -0.5352792 ]
#  [ 0.6570293  -0.77134596 -0.50305861]
#  [ 0.69300446 -0.77609627 -0.52804679]
#  [ 0.58005107 -0.88176433 -0.54071462]
#  [ 0.59833918 -0.77778925 -0.47006263]
#  [ 0.70381776 -0.7505473  -0.51776984]
#  [ 0.56624121 -0.88721458 -0.53828741]
#  [ 0.72379713 -0.85020722 -0.58564794]
#  [ 0.55611876 -0.88497608 -0.53212809]
#  [ 0.54138915 -0.84850225 -0.49645303]
#  [ 0.71975403 -0.87507988 -0.59611274]
#  [ 0.67526732 -0.72620226 -0.4812204 ]
#  [ 0.58823845 -0.91671147 -0.56679258]
#  [ 0.54824959 -0.79976906 -0.4568608 ]
#  [ 0.72409026 -0.88506132 -0.60243067]
#  [ 0.52758742 -0.86755859 -0.50512192]
#  [ 0.73046756 -0.88389438 -0.60428298]
#  [ 0.66320663 -0.93829256 -0.60564815]
#  [ 0.65103718 -0.71060223 -0.44992317]
#  [ 0.73204983 -0.89881341 -0.61144142]
#  [ 0.74394251 -0.72369839 -0.52577833]
#  [ 0.77044384 -0.82853883 -0.59509008]
#  [ 0.52541156 -0.9056643  -0.53368899]
#  [ 0.64652223 -0.70742871 -0.44342064]
#  [ 0.73964112 -0.90017465 -0.61467108]
#  [ 0.50327052 -0.85839062 -0.48478966]
#  [ 0.76941654 -0.86154985 -0.60913722]
#  [ 0.77895528 -0.75847446 -0.56534549]
#  [ 0.5220444  -0.79603321 -0.43547179]
#  [ 0.53305739 -0.93217321 -0.55531401]
#  [ 0.73414548 -0.92162783 -0.62169342]
#  [ 0.63980189 -0.69023374 -0.42153302]
#  [ 0.54343446 -0.9574546  -0.57510065]
#  [ 0.46802005 -0.9054514  -0.50880866]
#  [ 0.76171404 -0.67107699 -0.50490742]
#  [ 0.45790878 -0.89284165 -0.49336174]
#  [ 0.66074143 -0.65548516 -0.40733338]
#  [ 0.58019228 -1.00910457 -0.61409243]
#  [ 0.54383924 -0.72094175 -0.36559969]
#  [ 0.49138428 -0.76847045 -0.38003218]
#  [ 0.60416616 -1.02454038 -0.62732351]
#  [ 0.43465804 -0.90649777 -0.49526809]
#  [ 0.45987635 -0.79949598 -0.39533468]
#  [ 0.45558889 -0.79727754 -0.3893401 ]
#  [ 0.4231676  -0.86492759 -0.44891015]
#  [ 0.42206159 -0.86158263 -0.44470051]
#  [ 0.79272917 -0.6369473  -0.50658799]]
# Tracking distance between new barycenter and previous barycenter :  0.03220201632650338
# Iteration number :  18
# Input barycenter :
# [ 0.61421996 -0.83119823 -0.51684985]
# remaining indices
# [9375  260 4590 ... 2140 4897 8326]
# neighbours found :
# [[ 0.62026295 -0.82587201 -0.52132151]
#  [ 0.60600331 -0.8561461  -0.5352792 ]
#  [ 0.62389658 -0.79283621 -0.49879841]
#  [ 0.58005107 -0.88176433 -0.54071462]
#  [ 0.67496371 -0.79854525 -0.5324548 ]
#  [ 0.59833918 -0.77778925 -0.47006263]
#  [ 0.6570293  -0.77134596 -0.50305861]
#  [ 0.56624121 -0.88721458 -0.53828741]
#  [ 0.54138915 -0.84850225 -0.49645303]
#  [ 0.55611876 -0.88497608 -0.53212809]
#  [ 0.54824959 -0.79976906 -0.4568608 ]
#  [ 0.52758742 -0.86755859 -0.50512192]
#  [ 0.69300446 -0.77609627 -0.52804679]
#  [ 0.58823845 -0.91671147 -0.56679258]
#  [ 0.52541156 -0.9056643  -0.53368899]
#  [ 0.50327052 -0.85839062 -0.48478966]
#  [ 0.70381776 -0.7505473  -0.51776984]
#  [ 0.67526732 -0.72620226 -0.4812204 ]
#  [ 0.5220444  -0.79603321 -0.43547179]
#  [ 0.72379713 -0.85020722 -0.58564794]
#  [ 0.53305739 -0.93217321 -0.55531401]
#  [ 0.71975403 -0.87507988 -0.59611274]
#  [ 0.65103718 -0.71060223 -0.44992317]
#  [ 0.66320663 -0.93829256 -0.60564815]
#  [ 0.64652223 -0.70742871 -0.44342064]
#  [ 0.72409026 -0.88506132 -0.60243067]
#  [ 0.73046756 -0.88389438 -0.60428298]
#  [ 0.54343446 -0.9574546  -0.57510065]
#  [ 0.46802005 -0.9054514  -0.50880866]
#  [ 0.73204983 -0.89881341 -0.61144142]
#  [ 0.74394251 -0.72369839 -0.52577833]
#  [ 0.45790878 -0.89284165 -0.49336174]
#  [ 0.63980189 -0.69023374 -0.42153302]
#  [ 0.73964112 -0.90017465 -0.61467108]
#  [ 0.77044384 -0.82853883 -0.59509008]
#  [ 0.76941654 -0.86154985 -0.60913722]
#  [ 0.73414548 -0.92162783 -0.62169342]
#  [ 0.77895528 -0.75847446 -0.56534549]
#  [ 0.49138428 -0.76847045 -0.38003218]
#  [ 0.43465804 -0.90649777 -0.49526809]
#  [ 0.45987635 -0.79949598 -0.39533468]
#  [ 0.54383924 -0.72094175 -0.36559969]
#  [ 0.4231676  -0.86492759 -0.44891015]
#  [ 0.58019228 -1.00910457 -0.61409243]
#  [ 0.45558889 -0.79727754 -0.3893401 ]
#  [ 0.42206159 -0.86158263 -0.44470051]
#  [ 0.66074143 -0.65548516 -0.40733338]
#  [ 0.76171404 -0.67107699 -0.50490742]
#  [ 0.41022955 -0.8651712  -0.44237494]
#  [ 0.40676421 -0.89918215 -0.47616772]]
# Tracking distance between new barycenter and previous barycenter :  0.012541944176099879
# Iteration number :  19
# Input barycenter :
# [ 0.60262193 -0.83325554 -0.51254248]
# remaining indices
# [9375  260 4590 ... 2140 4897 8326]
# neighbours found :
# [[ 0.62026295 -0.82587201 -0.52132151]
#  [ 0.60600331 -0.8561461  -0.5352792 ]
#  [ 0.62389658 -0.79283621 -0.49879841]
#  [ 0.58005107 -0.88176433 -0.54071462]
#  [ 0.54138915 -0.84850225 -0.49645303]
#  [ 0.56624121 -0.88721458 -0.53828741]
#  [ 0.59833918 -0.77778925 -0.47006263]
#  [ 0.55611876 -0.88497608 -0.53212809]
#  [ 0.67496371 -0.79854525 -0.5324548 ]
#  [ 0.52758742 -0.86755859 -0.50512192]
#  [ 0.6570293  -0.77134596 -0.50305861]
#  [ 0.54824959 -0.79976906 -0.4568608 ]
#  [ 0.58823845 -0.91671147 -0.56679258]
#  [ 0.50327052 -0.85839062 -0.48478966]
#  [ 0.52541156 -0.9056643  -0.53368899]
#  [ 0.69300446 -0.77609627 -0.52804679]
#  [ 0.5220444  -0.79603321 -0.43547179]
#  [ 0.53305739 -0.93217321 -0.55531401]
#  [ 0.70381776 -0.7505473  -0.51776984]
#  [ 0.67526732 -0.72620226 -0.4812204 ]
#  [ 0.72379713 -0.85020722 -0.58564794]
#  [ 0.65103718 -0.71060223 -0.44992317]
#  [ 0.71975403 -0.87507988 -0.59611274]
#  [ 0.64652223 -0.70742871 -0.44342064]
#  [ 0.54343446 -0.9574546  -0.57510065]
#  [ 0.46802005 -0.9054514  -0.50880866]
#  [ 0.66320663 -0.93829256 -0.60564815]
#  [ 0.45790878 -0.89284165 -0.49336174]
#  [ 0.72409026 -0.88506132 -0.60243067]
#  [ 0.73046756 -0.88389438 -0.60428298]
#  [ 0.63980189 -0.69023374 -0.42153302]
#  [ 0.73204983 -0.89881341 -0.61144142]
#  [ 0.74394251 -0.72369839 -0.52577833]
#  [ 0.73964112 -0.90017465 -0.61467108]
#  [ 0.43465804 -0.90649777 -0.49526809]
#  [ 0.49138428 -0.76847045 -0.38003218]
#  [ 0.77044384 -0.82853883 -0.59509008]
#  [ 0.45987635 -0.79949598 -0.39533468]
#  [ 0.73414548 -0.92162783 -0.62169342]
#  [ 0.4231676  -0.86492759 -0.44891015]
#  [ 0.54383924 -0.72094175 -0.36559969]
#  [ 0.76941654 -0.86154985 -0.60913722]
#  [ 0.42206159 -0.86158263 -0.44470051]
#  [ 0.45558889 -0.79727754 -0.3893401 ]
#  [ 0.77895528 -0.75847446 -0.56534549]
#  [ 0.58019228 -1.00910457 -0.61409243]
#  [ 0.41022955 -0.8651712  -0.44237494]
#  [ 0.40676421 -0.89918215 -0.47616772]
#  [ 0.66074143 -0.65548516 -0.40733338]
#  [ 0.60416616 -1.02454038 -0.62732351]]
# Tracking distance between new barycenter and previous barycenter :  0.008117719009603968
# Iteration number :  20
# Input barycenter :
# [ 0.59947097 -0.84032481 -0.5149908 ]
# remaining indices
# [9375  260 2261 ... 2140 4897 8326]
# neighbours found :
# [[ 0.62026295 -0.82587201 -0.52132151]
#  [ 0.60600331 -0.8561461  -0.5352792 ]
#  [ 0.58005107 -0.88176433 -0.54071462]
#  [ 0.62389658 -0.79283621 -0.49879841]
#  [ 0.54138915 -0.84850225 -0.49645303]
#  [ 0.56624121 -0.88721458 -0.53828741]
#  [ 0.55611876 -0.88497608 -0.53212809]
#  [ 0.59833918 -0.77778925 -0.47006263]
#  [ 0.52758742 -0.86755859 -0.50512192]
#  [ 0.54824959 -0.79976906 -0.4568608 ]
#  [ 0.67496371 -0.79854525 -0.5324548 ]
#  [ 0.6570293  -0.77134596 -0.50305861]
#  [ 0.58823845 -0.91671147 -0.56679258]
#  [ 0.52541156 -0.9056643  -0.53368899]
#  [ 0.50327052 -0.85839062 -0.48478966]
#  [ 0.69300446 -0.77609627 -0.52804679]
#  [ 0.5220444  -0.79603321 -0.43547179]
#  [ 0.53305739 -0.93217321 -0.55531401]
#  [ 0.70381776 -0.7505473  -0.51776984]
#  [ 0.67526732 -0.72620226 -0.4812204 ]
#  [ 0.54343446 -0.9574546  -0.57510065]
#  [ 0.72379713 -0.85020722 -0.58564794]
#  [ 0.46802005 -0.9054514  -0.50880866]
#  [ 0.66320663 -0.93829256 -0.60564815]
#  [ 0.71975403 -0.87507988 -0.59611274]
#  [ 0.45790878 -0.89284165 -0.49336174]
#  [ 0.65103718 -0.71060223 -0.44992317]
#  [ 0.64652223 -0.70742871 -0.44342064]
#  [ 0.72409026 -0.88506132 -0.60243067]
#  [ 0.73046756 -0.88389438 -0.60428298]
#  [ 0.73204983 -0.89881341 -0.61144142]
#  [ 0.43465804 -0.90649777 -0.49526809]
#  [ 0.63980189 -0.69023374 -0.42153302]
#  [ 0.73964112 -0.90017465 -0.61467108]
#  [ 0.74394251 -0.72369839 -0.52577833]
#  [ 0.49138428 -0.76847045 -0.38003218]
#  [ 0.45987635 -0.79949598 -0.39533468]
#  [ 0.77044384 -0.82853883 -0.59509008]
#  [ 0.4231676  -0.86492759 -0.44891015]
#  [ 0.73414548 -0.92162783 -0.62169342]
#  [ 0.42206159 -0.86158263 -0.44470051]
#  [ 0.76941654 -0.86154985 -0.60913722]
#  [ 0.45558889 -0.79727754 -0.3893401 ]
#  [ 0.58019228 -1.00910457 -0.61409243]
#  [ 0.54383924 -0.72094175 -0.36559969]
#  [ 0.77895528 -0.75847446 -0.56534549]
#  [ 0.41022955 -0.8651712  -0.44237494]
#  [ 0.40676421 -0.89918215 -0.47616772]
#  [ 0.60416616 -1.02454038 -0.62732351]
#  [ 0.66074143 -0.65548516 -0.40733338]]
# Tracking distance between new barycenter and previous barycenter :  0.0
# Sampled barycenters are
# tensor([[ 1.7373, -1.2458, -0.2496],
#         [ 1.2880, -1.1083, -0.6575],
#         [ 0.5995, -0.8403, -0.5150]], dtype=torch.float64)
# Iteration number :  21
# Input barycenter :
# [ 0.59947097 -0.84032481 -0.5149908 ]
# remaining indices
# [5117 5509 7454 ... 2140 4897 8326]
# neighbours found :
# [[ 0.10522782 -1.09257287 -0.57279769]
#  [ 0.76175686 -0.37040421 -0.25227006]
#  [ 0.41610011 -1.34697309 -0.69416144]
#  [ 0.85071121 -0.34429176 -0.38855255]
#  [ 0.23831637 -0.76836525 -0.07902421]
#  [ 0.30421096 -1.30196197 -0.68076486]
#  [ 0.08855982 -1.09497572 -0.57344471]
#  [ 0.60719377 -1.38506722 -0.69989167]
#  [ 0.37543973 -1.34002705 -0.69156014]
#  [ 1.0406441  -0.48077477 -0.60408712]
#  [ 0.89096991 -0.34723061 -0.44082416]
#  [ 0.84534285 -0.33615986 -0.37627234]
#  [ 1.08472577 -0.54965603 -0.63981744]
#  [ 0.56161428 -1.38932667 -0.69999849]
#  [ 0.70117081 -0.41166141 -0.13470873]
#  [ 0.48648906 -0.63539616  0.01870259]
#  [ 0.6307612  -0.49454518 -0.04610821]
#  [ 0.03825609 -0.90005813 -0.36200024]
#  [ 0.02653463 -0.97585662 -0.46438313]
#  [ 0.16859751 -0.79112644 -0.1112189 ]
#  [ 0.26013198 -1.30143574 -0.67833092]
#  [ 0.32601015 -1.33975364 -0.68943618]
#  [ 0.48543303 -1.39494111 -0.69962178]
#  [ 0.45094484 -1.3885086  -0.69885047]
#  [ 0.37008107 -0.70959601  0.02062793]
#  [ 0.2218944  -1.27709484 -0.66968439]
#  [ 0.16598734 -1.23281032 -0.65148328]
#  [ 0.65152794 -1.41132054 -0.69787908]
#  [ 0.26426017 -1.3125644  -0.68121029]
#  [ 0.19550933 -1.26318219 -0.66393886]
#  [ 0.55924544 -0.57268167  0.02508794]
#  [ 0.60575396 -0.52255363  0.00036209]
#  [ 0.42974161 -1.39317866 -0.69873599]
#  [ 0.116962   -0.80750001 -0.14847127]
#  [ 0.76141213 -1.39724573 -0.69402831]
#  [ 1.03430652 -0.42168036 -0.58590269]
#  [ 0.57635815 -1.42165787 -0.69917152]
#  [ 0.56655099 -1.42150042 -0.69934638]
#  [ 0.23089796 -1.30120711 -0.67686787]
#  [ 0.89706538 -0.31176293 -0.43262624]
#  [ 0.0767483  -1.14714475 -0.60604983]
#  [ 0.93412043 -0.32718566 -0.47922701]
#  [ 0.67547363 -0.43364768 -0.06133493]
#  [ 0.12456814 -1.20957381 -0.6397872 ]
#  [ 0.7843571  -0.31688334 -0.24943611]
#  [ 0.72335404 -0.37168388 -0.13559721]
#  [ 0.56230889 -1.42688463 -0.69918902]
#  [ 0.80436339 -0.30576864 -0.28472007]
#  [ 0.86084691 -0.29633687 -0.37736036]
#  [ 0.83886709 -0.29544641 -0.34225167]]
# Tracking distance between new barycenter and previous barycenter :  0.11284555870535483
# Iteration number :  22
# Input barycenter :
# [ 0.5155541  -0.89378325 -0.46175289]
# remaining indices
# [5117 5013 8338 ... 9628 8388  168]
# neighbours found :
# [[ 0.10522782 -1.09257287 -0.57279769]
#  [ 0.08855982 -1.09497572 -0.57344471]
#  [ 0.03825609 -0.90005813 -0.36200024]
#  [ 0.23831637 -0.76836525 -0.07902421]
#  [ 0.02653463 -0.97585662 -0.46438313]
#  [ 0.16859751 -0.79112644 -0.1112189 ]
#  [ 0.30421096 -1.30196197 -0.68076486]
#  [ 0.116962   -0.80750001 -0.14847127]
#  [ 0.41610011 -1.34697309 -0.69416144]
#  [ 0.37543973 -1.34002705 -0.69156014]
#  [ 0.16598734 -1.23281032 -0.65148328]
#  [ 0.2218944  -1.27709484 -0.66968439]
#  [ 0.0767483  -1.14714475 -0.60604983]
#  [ 0.26013198 -1.30143574 -0.67833092]
#  [ 0.19550933 -1.26318219 -0.66393886]
#  [ 0.01703572 -1.0570614  -0.54215033]
#  [ 0.12456814 -1.20957381 -0.6397872 ]
#  [ 0.32601015 -1.33975364 -0.68943618]
#  [ 0.26426017 -1.3125644  -0.68121029]
#  [ 0.37008107 -0.70959601  0.02062793]
#  [ 0.23089796 -1.30120711 -0.67686787]
#  [ 0.48648906 -0.63539616  0.01870259]
#  [ 0.56161428 -1.38932667 -0.69999849]
#  [ 0.45094484 -1.3885086  -0.69885047]
#  [ 0.60719377 -1.38506722 -0.69989167]
#  [ 0.48543303 -1.39494111 -0.69962178]
#  [ 0.42974161 -1.39317866 -0.69873599]
#  [-0.04195806 -0.95319879 -0.43819744]
#  [ 0.10717077 -0.79765736 -0.08204472]
#  [ 0.21778072 -0.76986025  0.00995421]
#  [ 0.09661385 -0.79907028 -0.08259407]
#  [-0.03917095 -0.86688589 -0.30047589]
#  [ 0.37520143 -0.71042794  0.06911249]
#  [ 0.56655099 -1.42150042 -0.69934638]
#  [ 0.57635815 -1.42165787 -0.69917152]
#  [-0.02098594 -1.0971066  -0.57257191]
# ...
#  [-1.97780645  0.74774946 -0.33535962]
#  [-2.02075989  0.37989745 -0.42507225]
#  [-1.98020133  0.75954542 -0.32328852]
#  [-1.95009607  0.37961323 -0.50311245]
#  [-2.10589372  0.40990643 -0.27099379]
#  [-2.10185523  0.39394588 -0.28701136]
#  [-2.01947719  0.33410022 -0.43688741]
#  [-2.11655992  0.42104396 -0.23873276]
#  [-2.1182216   0.43045106 -0.22890337]
#  [-1.87179938  0.77266647 -0.46300049]
#  [-1.90178262  0.8020109  -0.41464517]
#  [-1.98805338  0.32322092 -0.47501861]
#  [-1.99429776  0.31791224 -0.46919348]
#  [-1.86642783  0.8099458  -0.45189742]
#  [-1.96391611  0.30203714 -0.5028172 ]
#  [-2.13329398  0.45720398 -0.15885191]
#  [-1.99680299  0.28419409 -0.47200427]
#  [-2.10961641  0.29678099 -0.30431694]
#  [-2.13657303  0.46069617 -0.14087809]
#  [-1.84936818  0.8390604  -0.45633524]
#  [-2.05277596  0.25852417 -0.40773668]
#  [-1.84169658  0.83925432 -0.4642444 ]
#  [-2.09826836  0.26630874 -0.3341426 ]
#  [-2.0470295   0.24112237 -0.41841984]
#  [-2.05432518  0.23533728 -0.40944773]
#  [-2.14643182  0.30898831 -0.20743757]
#  [-2.15358921  0.35376723 -0.15575286]
#  [-2.08621479  0.18574984 -0.36960532]
#  [-1.83910481  0.93704749 -0.41452458]
#  [-1.85877141  0.94627773 -0.38322752]
#  [-1.79333484  0.95307848 -0.45627125]
#  [-2.10271431  0.1356933  -0.34848827]
#  [-2.03415967  0.11577581 -0.44849261]
#  [-1.78531958  0.97619693 -0.45167598]]
# Tracking distance between new barycenter and previous barycenter :  0.053637233959044066
# Iteration number :  677
# Input barycenter :
# [-1.99807001  0.51263502 -0.38062151]
# remaining indices
# [2316 5439 1069 2472 6350 2895 6148 2692 9283 9523 4198  135 3264 1420
#  3890 8962 2780  864 5758 8810 9551 5366 5018 9362 3977 8911  571 3574
#  9579 7775 9715 6538 4918 4710 4941  833 2241 6739 1324 5994 8469 2101
#   413 4278 7744 5400 1155 1869  808 3946  300 7157 2809 7969 2986 8461
#  1705 9629 6150 8204 8926 1701 6576 7854 3352 2687  828 2357 9586 3915
#  8630 5862 9923 4497 8191 7650 8156 9509 3136  684  752 1756 2748 8819
#  3284 4129 2601 8007 7121 7437 3760 3606 4164 5575 9383 2266 3913 9639
#  7971 1351 7333  588  241 8258 1453 3556 1942  583 2394 8495 6029 2169
#   932 9050  949 8304 6232 8029 1999 9808 9513 6580 9490 2915 3716 5099
#  1163 4620 2473 5246 3084  971 7966 7590 5612 1238 1308 4398 9210 5547
#  7697 3839 7496 4205 6825 3054 4982 1583 1550 3878  232 9116 2575 6160
#  5583 4082 7688 6838 2722 4359 5288 7875 7490 9723 3645 8898 9954 5353
#  6929  563 5759 9756 1434  175  520 2042 8701 7691 4096  436 6962 9660
#  8375 8579 3776 6423 5130 6519 9481 9684  831  213  293 8869 2448 9437
#  6289 1281 1437  617]
# neighbours found :
# [[-1.96474583  0.527476   -0.45221934]
#  [-2.01800873  0.44002365 -0.41266775]
#  [-1.95175126  0.51755731 -0.46949299]
#  [-2.0058265   0.62535498 -0.35880295]
#  [-2.0000318   0.63107032 -0.3651238 ]
#  [-1.94945772  0.46979225 -0.48446534]
#  [-1.94754205  0.60374752 -0.44665732]
#  [-2.03055159  0.62706662 -0.3148985 ]
#  [-1.93121526  0.48708858 -0.49823322]
#  [-2.08305469  0.4235748  -0.31387823]
#  [-1.98300748  0.40084051 -0.46513584]
#  [-2.02075989  0.37989745 -0.42507225]
#  [-1.92143373  0.51525465 -0.50056541]
#  [-2.04926351  0.6123085  -0.2862749 ]
#  [-1.96370438  0.66972049 -0.39955257]
#  [-2.00765167  0.6720548  -0.33034261]
#  [-2.10185523  0.39394588 -0.28701136]
#  [-2.10589372  0.40990643 -0.27099379]
#  [-1.95009607  0.37961323 -0.50311245]
#  [-2.01947719  0.33410022 -0.43688741]
#  [-2.11655992  0.42104396 -0.23873276]
#  [-2.1182216   0.43045106 -0.22890337]
#  [-1.98805338  0.32322092 -0.47501861]
#  [-1.99429776  0.31791224 -0.46919348]
#  [-1.99971531  0.73371584 -0.30497736]
#  [-1.97780645  0.74774946 -0.33535962]
#  [-1.96391611  0.30203714 -0.5028172 ]
#  [-1.99680299  0.28419409 -0.47200427]
#  [-1.98020133  0.75954542 -0.32328852]
#  [-2.10961641  0.29678099 -0.30431694]
#  [-2.05277596  0.25852417 -0.40773668]
#  [-2.13329398  0.45720398 -0.15885191]
#  [-2.09826836  0.26630874 -0.3341426 ]
#  [-2.0470295   0.24112237 -0.41841984]
#  [-2.13657303  0.46069617 -0.14087809]
#  [-2.05432518  0.23533728 -0.40944773]
#  [-1.87179938  0.77266647 -0.46300049]
#  [-2.14643182  0.30898831 -0.20743757]
#  [-1.90178262  0.8020109  -0.41464517]
#  [-2.15358921  0.35376723 -0.15575286]
#  [-1.86642783  0.8099458  -0.45189742]
#  [-2.08621479  0.18574984 -0.36960532]
#  [-1.84936818  0.8390604  -0.45633524]
#  [-1.84169658  0.83925432 -0.4642444 ]
#  [-2.10271431  0.1356933  -0.34848827]
#  [-2.03415967  0.11577581 -0.44849261]
#  [-2.10467648  0.07547111 -0.35032643]
#  [-1.83910481  0.93704749 -0.41452458]
#  [-1.85877141  0.94627773 -0.38322752]
#  [-2.10875492  0.05608509 -0.34425136]]
# Tracking distance between new barycenter and previous barycenter :  0.0383680214911713
# Iteration number :  678
# Input barycenter :
# [-2.01076555  0.47668064 -0.37635412]
# remaining indices
# [5439 2316  135 9523 1069 4198 2895 9283 2472 2780 8810 6350  864 3264
#  6148 2692 1420 5758 9551 5018 9362 5366 3890 8962 3574 7775  571 9715
#  4918 4710  833 6538 3977 4941 6739 8911 9579 5994 2101 2241 1324 7744
#  5400 8469  413 4278 1155 3946  300 2809 8461 1869  808 7157 6150 8204
#  7969 2986 1705 9629 3352 8926 3915 1701 6576 7854 5862 2687  828 2357
#  9586 8630 4497 8191 9923 7650 8156 9509 3136  752  684 1756 2748 8819
#  3284 4129 2601 8007 7121 7437 3760 3606 4164 5575 9383 2266 3913 9639
#  7971 1351 7333  588  241 8258 1453 3556 1942  583 2394 8495 6029 2169
#   932 9050 6232 8304  949 8029 1999 9808 9513 9490 6580 2915 3716 1163
#  5099 4620 2473 5246 3084  971 7966 7590 5612 1238 1308 4398 9210 5547
#  7697 3839 7496 4205 6825 3054 4982 1583 1550 3878  232 9116 2575 6160
#  5583 4082 7688 2722 6838 4359 5288 7875 7490 3645 9723 8898 5353 6929
#  9954  563 5759 9756  175 1434 2042  520 8701 7691  436 4096 6962 9660
#  8375 8579 3776 6423 5130 9481 6519 9684  831 8869  213  293 2448 9437
#  6289 1281 1437  617]
# neighbours found :
# [[-2.01800873  0.44002365 -0.41266775]
#  [-1.96474583  0.527476   -0.45221934]
#  [-2.02075989  0.37989745 -0.42507225]
#  [-2.08305469  0.4235748  -0.31387823]
#  [-1.95175126  0.51755731 -0.46949299]
#  [-1.98300748  0.40084051 -0.46513584]
#  [-1.94945772  0.46979225 -0.48446534]
#  [-1.93121526  0.48708858 -0.49823322]
#  [-2.0058265   0.62535498 -0.35880295]
#  [-2.10185523  0.39394588 -0.28701136]
#  [-2.01947719  0.33410022 -0.43688741]
#  [-2.0000318   0.63107032 -0.3651238 ]
#  [-2.10589372  0.40990643 -0.27099379]
#  [-1.92143373  0.51525465 -0.50056541]
#  [-1.94754205  0.60374752 -0.44665732]
#  [-2.03055159  0.62706662 -0.3148985 ]
#  [-2.04926351  0.6123085  -0.2862749 ]
#  [-1.95009607  0.37961323 -0.50311245]
#  [-2.11655992  0.42104396 -0.23873276]
#  [-1.98805338  0.32322092 -0.47501861]
#  [-1.99429776  0.31791224 -0.46919348]
#  [-2.1182216   0.43045106 -0.22890337]
#  [-1.96370438  0.66972049 -0.39955257]
#  [-2.00765167  0.6720548  -0.33034261]
#  [-1.99680299  0.28419409 -0.47200427]
#  [-2.10961641  0.29678099 -0.30431694]
#  [-1.96391611  0.30203714 -0.5028172 ]
#  [-2.05277596  0.25852417 -0.40773668]
#  [-2.09826836  0.26630874 -0.3341426 ]
#  [-2.0470295   0.24112237 -0.41841984]
#  [-2.05432518  0.23533728 -0.40944773]
#  [-2.13329398  0.45720398 -0.15885191]
#  [-1.99971531  0.73371584 -0.30497736]
#  [-2.13657303  0.46069617 -0.14087809]
#  [-2.14643182  0.30898831 -0.20743757]
#  [-1.97780645  0.74774946 -0.33535962]
#  [-1.98020133  0.75954542 -0.32328852]
#  [-2.15358921  0.35376723 -0.15575286]
#  [-2.08621479  0.18574984 -0.36960532]
#  [-1.87179938  0.77266647 -0.46300049]
#  [-1.90178262  0.8020109  -0.41464517]
#  [-2.10271431  0.1356933  -0.34848827]
#  [-2.03415967  0.11577581 -0.44849261]
#  [-1.86642783  0.8099458  -0.45189742]
#  [-1.84936818  0.8390604  -0.45633524]
#  [-1.84169658  0.83925432 -0.4642444 ]
#  [-2.10467648  0.07547111 -0.35032643]
#  [-2.10875492  0.05608509 -0.34425136]
#  [-2.12438588  0.05849504 -0.31485892]
#  [-2.1509904   0.05449672 -0.2555628 ]]
# Tracking distance between new barycenter and previous barycenter :  0.037519413564215585
# Iteration number :  679
# Input barycenter :
# [-2.02231555  0.44127397 -0.37180752]
# remaining indices
# [5439  135 9523 4198 8810 2780 2316  864 2895 1069 9362 5018 5758 9283
#  9551 5366 3264 7775 2472 3574 9715 6350 1420 6148 4918 2692  571 4710
#   833 8962 3890 6538 6739 4941 2101 5994 3977 8911 7744 9579 5400 2241
#  1155 1324 3946  300 8469 2809  413 8461 4278 6150 8204 1869  808 3352
#  7157 7969 2986 1705 3915 9629 5862 8926 1701 6576 7854 4497 8191 2687
#   828 2357 9586 7650 8630 8156 9923 9509  752 3136  684 1756 2748 8819
#  3284 4129 2601 7121 8007 7437 3760 3606 4164 5575 9383 2266 3913 9639
#  7971 1351 7333  588  241 8258 1453 3556 1942  583 2394 8495 6029 2169
#  6232  932 9050 8304  949 8029 1999 9808 9513 9490 6580 2915 3716 1163
#  5099 4620 2473 5246 3084  971 7966 7590 5612 1238 1308 4398 9210 5547
#  7697 3839 7496 4205 6825 3054 4982 1583 1550 3878  232 9116 2575 6160
#  5583 4082 7688 2722 6838 4359 5288 7875 7490 3645 8898 9723 6929 5353
#   563 9954 9756 5759  175 1434 2042  520 7691 8701  436 4096 8375 9660
#  8579 6962 3776 6423 5130 9481 6519 9684 8869  831  213  293 2448 9437
#  6289 1437 1281  617]
# neighbours found :
# [[-2.01800873  0.44002365 -0.41266775]
#  [-2.02075989  0.37989745 -0.42507225]
#  [-2.08305469  0.4235748  -0.31387823]
#  [-1.98300748  0.40084051 -0.46513584]
#  [-2.01947719  0.33410022 -0.43688741]
#  [-2.10185523  0.39394588 -0.28701136]
#  [-1.96474583  0.527476   -0.45221934]
#  [-2.10589372  0.40990643 -0.27099379]
#  [-1.94945772  0.46979225 -0.48446534]
#  [-1.95175126  0.51755731 -0.46949299]
#  [-1.99429776  0.31791224 -0.46919348]
#  [-1.98805338  0.32322092 -0.47501861]
#  [-1.95009607  0.37961323 -0.50311245]
#  [-1.93121526  0.48708858 -0.49823322]
#  [-2.11655992  0.42104396 -0.23873276]
#  [-2.1182216   0.43045106 -0.22890337]
#  [-1.92143373  0.51525465 -0.50056541]
#  [-2.10961641  0.29678099 -0.30431694]
#  [-2.0058265   0.62535498 -0.35880295]
#  [-1.99680299  0.28419409 -0.47200427]
#  [-2.05277596  0.25852417 -0.40773668]
#  [-2.0000318   0.63107032 -0.3651238 ]
#  [-2.04926351  0.6123085  -0.2862749 ]
#  [-1.94754205  0.60374752 -0.44665732]
#  [-2.09826836  0.26630874 -0.3341426 ]
#  [-2.03055159  0.62706662 -0.3148985 ]
#  [-1.96391611  0.30203714 -0.5028172 ]
#  [-2.0470295   0.24112237 -0.41841984]
#  [-2.05432518  0.23533728 -0.40944773]
#  [-2.00765167  0.6720548  -0.33034261]
#  [-1.96370438  0.66972049 -0.39955257]
#  [-2.13329398  0.45720398 -0.15885191]
#  [-2.14643182  0.30898831 -0.20743757]
#  [-2.13657303  0.46069617 -0.14087809]
#  [-2.08621479  0.18574984 -0.36960532]
#  [-2.15358921  0.35376723 -0.15575286]
#  [-1.99971531  0.73371584 -0.30497736]
#  [-1.97780645  0.74774946 -0.33535962]
#  [-2.10271431  0.1356933  -0.34848827]
#  [-1.98020133  0.75954542 -0.32328852]
#  [-2.03415967  0.11577581 -0.44849261]
#  [-1.87179938  0.77266647 -0.46300049]
#  [-2.10467648  0.07547111 -0.35032643]
#  [-1.90178262  0.8020109  -0.41464517]
#  [-2.10875492  0.05608509 -0.34425136]
#  [-2.12438588  0.05849504 -0.31485892]
#  [-1.86642783  0.8099458  -0.45189742]
#  [-2.1509904   0.05449672 -0.2555628 ]
#  [-1.84936818  0.8390604  -0.45633524]
#  [-2.11926321  0.00782082 -0.32633604]]
# Tracking distance between new barycenter and previous barycenter :  0.01774647701605957
# Iteration number :  680
# Input barycenter :
# [-2.02786689  0.4246453  -0.36904935]
# remaining indices
# [5439  135 9523 4198 8810 2780  864 2316 2895 9362 5018 1069 9551 5758
#  7775 5366 9715 9283 4918 3574 4710 3264  571  833 2472 1420 6350 2692
#  6148 6739 6538 2101 8962 3890 4941 5994 7744 3977 5400 8911 9579 1155
#  3946  300 2241 1324 2809 8469 8461  413 4278 6150 8204 3352 1869  808
#  7157 3915 7969 5862 2986 1705 9629 8926 1701 6576 7854 4497 8191 7650
#  2687  828 2357 9586 8156 8630 9923 9509  752 3136 1756  684 2748 3284
#  4129 8819 2601 7121 8007 7437 3760 3606 4164 5575 9383 2266 3913 9639
#  7971 1351 7333  588  241 8258 1453 3556 1942  583 2394 8495 6029 2169
#  6232  932 9050 8304  949 1999 8029 9808 9513 9490 6580 3716 2915 1163
#  5099 4620 2473 5246 3084  971 7966 7590 5612 1238 1308 4398 9210 5547
#  7697 3839 7496 4205 6825 3054 4982 1583 1550 3878  232 9116 2575 6160
#  5583 4082 7688 2722 6838 4359 5288 7875 7490 3645 8898 9723 6929  563
#  5353 9954 9756 5759  175 1434 2042 7691  520  436 8701 4096 8375 9660
#  8579 3776 6962 6423 5130 9481 6519 9684 8869  831  213  293 2448 9437
#  6289 1437 1281  617]
# neighbours found :
# [[-2.01800873  0.44002365 -0.41266775]
#  [-2.02075989  0.37989745 -0.42507225]
#  [-2.08305469  0.4235748  -0.31387823]
#  [-1.98300748  0.40084051 -0.46513584]
#  [-2.01947719  0.33410022 -0.43688741]
#  [-2.10185523  0.39394588 -0.28701136]
#  [-2.10589372  0.40990643 -0.27099379]
#  [-1.96474583  0.527476   -0.45221934]
#  [-1.94945772  0.46979225 -0.48446534]
#  [-1.99429776  0.31791224 -0.46919348]
#  [-1.98805338  0.32322092 -0.47501861]
#  [-1.95175126  0.51755731 -0.46949299]
#  [-2.11655992  0.42104396 -0.23873276]
#  [-1.95009607  0.37961323 -0.50311245]
#  [-2.10961641  0.29678099 -0.30431694]
#  [-2.1182216   0.43045106 -0.22890337]
#  [-2.05277596  0.25852417 -0.40773668]
#  [-1.93121526  0.48708858 -0.49823322]
#  [-2.09826836  0.26630874 -0.3341426 ]
#  [-1.99680299  0.28419409 -0.47200427]
#  [-2.0470295   0.24112237 -0.41841984]
#  [-1.92143373  0.51525465 -0.50056541]
#  [-1.96391611  0.30203714 -0.5028172 ]
#  [-2.05432518  0.23533728 -0.40944773]
#  [-2.0058265   0.62535498 -0.35880295]
#  [-2.04926351  0.6123085  -0.2862749 ]
#  [-2.0000318   0.63107032 -0.3651238 ]
#  [-2.03055159  0.62706662 -0.3148985 ]
#  [-1.94754205  0.60374752 -0.44665732]
#  [-2.14643182  0.30898831 -0.20743757]
#  [-2.13329398  0.45720398 -0.15885191]
#  [-2.08621479  0.18574984 -0.36960532]
#  [-2.00765167  0.6720548  -0.33034261]
#  [-1.96370438  0.66972049 -0.39955257]
#  [-2.13657303  0.46069617 -0.14087809]
#  [-2.15358921  0.35376723 -0.15575286]
#  [-2.10271431  0.1356933  -0.34848827]
#  [-1.99971531  0.73371584 -0.30497736]
#  [-2.03415967  0.11577581 -0.44849261]
#  [-1.97780645  0.74774946 -0.33535962]
#  [-1.98020133  0.75954542 -0.32328852]
#  [-2.10467648  0.07547111 -0.35032643]
#  [-2.10875492  0.05608509 -0.34425136]
#  [-2.12438588  0.05849504 -0.31485892]
#  [-1.87179938  0.77266647 -0.46300049]
#  [-1.90178262  0.8020109  -0.41464517]
#  [-2.1509904   0.05449672 -0.2555628 ]
#  [-1.86642783  0.8099458  -0.45189742]
#  [-2.11926321  0.00782082 -0.32633604]
#  [-1.84936818  0.8390604  -0.45633524]]
# Tracking distance between new barycenter and previous barycenter :  0.0
# Sampled barycenters are
# tensor([[ 1.7373, -1.2458, -0.2496],
#         [ 1.2880, -1.1083, -0.6575],
#         [ 0.5995, -0.8403, -0.5150],
#         [-0.1431, -1.1046, -0.5762],
#         [-0.9703, -1.4793, -0.6384],
#         [-1.5448, -1.3524, -0.4144],
#         [-1.9411, -0.7582, -0.3712],
#         [-1.4643, -0.0394, -0.6905],
#         [-1.4266,  0.6300, -0.6884],
#         [-1.2872,  1.3460, -0.5890],
#         [-1.0262,  1.8681, -0.2537],
#         [-0.9134,  1.7149,  0.5263],
#         [-0.8013,  0.9510,  0.6425],
#         [-1.4110,  0.4720,  0.6899],
#         [-1.9727,  0.2157,  0.4901],
#         [-1.9047, -0.6555,  0.4550],
#         [-0.7488, -0.8959,  0.6097],
#         [-0.1087, -0.8941,  0.3572],
#         [ 0.4922, -1.1724,  0.6518],
#         [ 0.8439, -1.7862,  0.4991],
#         [ 1.3735, -1.3151,  0.5610],
#         [ 1.6969, -0.6599,  0.6116],
#         [ 1.3981,  0.0584,  0.6809],
#         [ 1.6672,  0.6862,  0.6234],
#         [ 1.3661,  1.2980,  0.5756],
#         [ 0.7283,  1.6479,  0.6208],
#         [-0.0130,  1.7109,  0.6570],
#         [ 0.2723,  0.9909,  0.5094],
#         [ 0.8034,  0.3879,  0.3349],
#         [ 0.9906,  0.1725, -0.4891],
#         [ 1.7371,  0.4046, -0.6288],
#         [ 1.6675,  1.0926, -0.4850],
#         [ 1.2667,  1.6639, -0.3562],
#         [ 0.5851,  1.6349, -0.6500],
#         [-0.1112,  1.6752, -0.6668],
#         [-0.4076,  0.9982, -0.5492],
#         [-0.7011,  0.4024, -0.1042],
#         [-0.7092, -0.4107,  0.1491],
#         [-0.9966, -0.6389, -0.6155],
#         [-1.3036, -1.6778,  0.2777],
#         [-0.5483, -1.5577,  0.6757],
#         [ 0.0502, -1.9692,  0.4960],
#         [ 0.3084, -1.7905, -0.6116],
#         [ 1.1708, -1.7867, -0.2707],
#         [ 0.8063, -0.4966,  0.4165],
#         [ 1.8282, -0.3569, -0.5791],
#         [ 0.8344,  0.9941, -0.6535],
#         [ 1.2504,  1.5859,  0.1462],
#         [-1.7772,  1.0348,  0.4031],
#         [-2.0279,  0.4246, -0.3690]], dtype=torch.float64)
# END

# %%
sampled_barycenters.shape
# Out:
# torch.Size([50, 3])

# %% [markdown]
# # using the function

# %%
torus_bary = get_convergent_barycenters(point_data_torus, 200, point_data_torus[0])

# %%
torus_bary.shape
# Out:
# torch.Size([200, 3])

# %%
# plotting the sampled barycenters

x_stb = torus_bary[:,0]#.cpu().detach().numpy()

y_stb = torus_bary[:,1]#.cpu().detach().numpy()

z_stb = torus_bary[:,2]#.cpu().detach().numpy()



plot_points = [x_stb,y_stb,z_stb]
Points(plot_points).show(axes=1)
# Out:
# ViewInteractiveWidget(height=960, layout=Layout(height='auto', width='100%'), width=960)

# %% [markdown]
# # Trajectory of barycenter smpling

# %%
fig = matplotlib.pyplot.figure()
ax  = fig.add_subplot(111, projection = '3d')

X = torus_bary[:,0]
Y = torus_bary[:,1]
Z = torus_bary[:,2]
ax.plot(X, Y, Z, color = 'b')
plt.show()

# %% [markdown]
# # Persistent homology of sampled barycenters

# %%
torus_PH_arrays,PH_diagram_barycenters_torus = get_persistence_diagram(torus_bary,2)
# Out:
# /tmp/ipykernel_45793/1703124144.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   point_cloud = torch.tensor(point_cloud)

# %% [markdown]
# # Sphere

# %%
expr = x**2 + y**2 + z**2 - 1
poly = sp.Poly(expr, x, y, z)

# %%
expr
# Out:
# x**2 + y**2 + z**2 - 1

# %%
    # convert sympy polynomial to minyterpy polynomial
newt_poly = sympy_to_mp(poly, mp.NewtonPolynomial)

# %%
#sample points
point_data = sample_points_on_poly(1000,        # Number of points to be sampled
                                   newt_poly,  # Polynomial in Newton basis
                                   bounds=1, # Boundary of the Cubic domain to be sampled
                                   tol=1e-15)  # Tolerance in solution

# %%
point_data.shape
# Out:
# (1000, 3)

# %%
x_so = point_data[:,0]

y_so = point_data[:,1]

z_so = point_data[:,2]


plot_points = [x_so,y_so,z_so]
Points(plot_points).show(axes=1)
# Out:
# ViewInteractiveWidget(height=960, layout=Layout(height='auto', width='100%'), width=960)

# %%
sphere_bary = get_convergent_barycenters(point_data, 50, point_data[0])

# %%
sphere_bary.shape
# Out:
# torch.Size([50, 3])

# %% [markdown]
# # Trajectory of barycenter smpling on sphere

# %%
fig = matplotlib.pyplot.figure()
ax  = fig.add_subplot(111, projection = '3d')

X = sphere_bary[:,0]
Y = sphere_bary[:,1]
Z = sphere_bary[:,2]
ax.plot(X, Y, Z, color = 'b')
plt.show()

# %%
x_sb = sphere_bary[:,0]#.cpu().detach().numpy()

y_sb = sphere_bary[:,1]#.cpu().detach().numpy()

z_sb = sphere_bary[:,2]#.cpu().detach().numpy()



plot_points = [x_sb,y_sb,z_sb]
Points(plot_points).show(axes=1)
# Out:
# ViewInteractiveWidget(height=960, layout=Layout(height='auto', width='100%'), width=960)

# %%
#original point cloud sphere persistence diagram

PH_diagram_spheres = get_persistence_diagram(point_data,1)

# %%
# barycentyers of sphere persistence diagram


PH_diagram_barycenters_sphere = get_persistence_diagram(sphere_bary, 1)
# Out:
# /tmp/ipykernel_45793/1703124144.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   point_cloud = torch.tensor(point_cloud)
